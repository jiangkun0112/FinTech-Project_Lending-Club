# %% [markdown]
# <h1 id="tocheading">Table of Contents</h1>
# <div id="toc"></div>

# %%
# %%javascript
# $.getScript('https://kmahelona.github.io/ipython_notebook_goodies/ipython_notebook_toc.js')

# %% [markdown]
# # Prerequisites
# Please make sure the following Python distributions and packages were installed.
#
# * [Anaconda](https://anaconda.org)
# * [XGBoost](https://github.com/dmlc/xgboost)
# * [seaborn](https://seaborn.pydata.org)
#
# You'll also need to create the following sub-folders in your working folder:
#
# * data
#
#    To store all the data files downloaded from Lending Club
#    To store processed data file

# %% [markdown]
# # Data Processing

# %% [markdown]
# * Fetch current listed loans from lending club website api, save as current_list.txt
#
# * Unify feature formats for current loans (i.e. change the name to lower case) and 2014 loans (i.e. remove '_')
#
# * Find common features of current and 2014 loans, (92 common feature in total),  only keep common features shared by both current and 2014 loans
# * save to loan_2014_processed.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import json
import requests

# %% [markdown]
# # 1. Get Current Data from Lending Club API
#
# current loan data that are available for investing right now is downloanded from Lending Club API. Current loan data is useful to find out which featues about loans are currently provided by Lending Club and can be used to compare the difference to historical data
#
# The Apikey was copied from API interface and saved in apikeys.txt,

# %%
# Use lending club website to download data
# api key is saved in apikeys.txt
api_key =open('apikeys.txt','r').read()

headers = {'Authorization':api_key}
url='https://api.lendingclub.com/api/investor/v1/loans/listing'

r=requests.get(url, headers=headers)

# %%
# loan data saved in r.json()
type(r.json())
# Out:
# dict

# %%
r.json()
# Out:
# {'asOfDate': '2018-05-12T17:38:33.414-07:00',
#  'loans': [{'accNowDelinq': 0,
#    'accOpenPast24Mths': 1,
#    'acceptD': '2018-05-12T13:31:59.000-07:00',
#    'addrState': 'IL',
#    'addrZip': '604xx',
#    'allUtil': 64.9,
#    'annualInc': 30000.0,
#    'annualIncJoint': 97000.0,
#    'applicationType': 'JOINT',
#    'avgCurBal': 21459,
#    'bcOpenToBuy': 574,
#    'bcUtil': 64.1,
#    'chargeoffWithin12Mths': 0,
#    'collections12MthsExMed': 0,
#    'creditPullD': '2018-05-12T13:21:12.000-07:00',
#    'delinq2Yrs': 0,
#    'delinqAmnt': 0.0,
#    'desc': None,
#    'disbursementMethod': 'CASH',
#    'dti': 12.2,
#    'dtiJoint': 15.25,
#    'earliestCrLine': '1991-06-11T17:00:00.000-07:00',
#    'empLength': 0,
#    'empTitle': 'Trimmer',
#    'expD': '2018-06-11T14:00:00.000-07:00',
#    'expDefaultRate': 3.95,
#    'ficoRangeHigh': 744,
#    'ficoRangeLow': 740,
#    'fundedAmount': 2650.0,
#    'grade': 'B',
#    'homeOwnership': 'MORTGAGE',
#    'housingPayment': 997.0,
#    'iLUtil': 56.2,
#    'id': 133312234,
#    'ilsExpD': '2018-05-12T14:00:00.000-07:00',
#    'initialListStatus': 'F',
#    'inqFi': 1,
#    'inqLast12m': 0,
#    'inqLast6Mths': 0,
#    'installment': 161.51,
#    'intRate': 10.07,
#    'investorCount': None,
#    'isIncV': 'NOT_VERIFIED',
#    'isIncVJoint': 'NOT_VERIFIED',
#    'listD': '2018-05-12T14:00:00.000-07:00',
#    'loanAmount': 5000.0,
#    'maxBalBc': 981.0,
#    'memberId': 150320047,
#    'moSinOldIlAcct': 100,
#    'moSinOldRevTlOp': 323,
#    'moSinRcntRevTlOp': 49,
#    'moSinRcntTl': 22,
#    'mortAcc': 1,
#    'mtgPayment': 996.68,
#    'mthsSinceLastDelinq': None,
#    'mthsSinceLastMajorDerog': None,
#    'mthsSinceLastRecord': None,
#    'mthsSinceRcntIl': 22,
#    'mthsSinceRecentBc': 49,
#    'mthsSinceRecentBcDlq': None,
#    'mthsSinceRecentInq': 22,
#    'mthsSinceRecentRevolDelinq': None,
#    'numAcctsEver120Ppd': 0,
#    'numActvBcTl': 2,
#    'numActvRevTl': 3,
#    'numBcSats': 2,
#    'numBcTl': 2,
#    'numIlTl': 6,
#    'numOpRevTl': 3,
#    'numRevAccts': 4,
#    'numRevTlBalGt0': 3,
#    'numSats': 5,
#    'numTl120dpd2m': 0,
#    'numTl30dpd': 0,
#    'numTl90gDpd24m': 0,
#    'numTlOpPast12m': 0,
#    'openAcc': 5,
#    'openAcc6m': 0,
#    'openActIl': 1,
#    'openIl12m': 0,
#    'openIl24m': 1,
#    'openRv12m': 0,
#    'openRv24m': 0,
#    'pctTlNvrDlq': 100,
#    'percentBcGt75': 50.0,
#    'pubRec': 0,
#    'pubRecBankruptcies': 0,
#    'purpose': 'car',
#    'reviewStatus': 'APPROVED',
#    'reviewStatusD': '2018-05-12T13:40:23.000-07:00',
#    'revolBal': 5132.0,
#    'revolBalJoint': 9688,
#    'revolUtil': 68.4,
#    'secAppChargeoffWithin12Mths': 0,
#    'secAppCollections12MthsExMed': 1,
#    'secAppEarliestCrLine': '2001-08-10T17:00:00.000-07:00',
#    'secAppFicoRangeHigh': 624,
#    'secAppFicoRangeLow': 620,
#    'secAppInqLast6Mths': 1,
#    'secAppMortAcc': 1,
#    'secAppMthsSinceLastMajorDerog': 16,
#    'secAppNumRevAccts': 16,
#    'secAppOpenAcc': 8,
#    'secAppOpenActIl': 3,
#    'secAppRevolUtil': 51.2,
#    'serviceFeeRate': 0.97,
#    'subGrade': 'B2',
#    'taxLiens': 0,
#    'term': 36,
#    'totCollAmt': 0,
#    'totCurBal': 107295,
#    'totHiCredLim': 122353,
#    'totalAcc': 11,
#    'totalBalExMort': 6827,
#    'totalBalIl': 1695.0,
#    'totalBcLimit': 1600,
#    'totalCuTl': 0,
#    'totalIlHighCreditLimit': 3017,
#    'totalRevHiLim': 7500},
#   {'accNowDelinq': 0,
#    'accOpenPast24Mths': 7,
#    'acceptD': '2018-05-12T12:52:47.000-07:00',
#    'addrState': 'CA',
#    'addrZip': '957xx',
#    'allUtil': 90.1,
#    'annualInc': 40000.0,
#    'annualIncJoint': None,
#    'applicationType': 'INDIVIDUAL',
#    'avgCurBal': 4876,
#    'bcOpenToBuy': 3277,
#    'bcUtil': 58.5,
#    'chargeoffWithin12Mths': 0,
#    'collections12MthsExMed': 0,
#    'creditPullD': '2018-05-12T12:46:54.000-07:00',
#    'delinq2Yrs': 0,
#    'delinqAmnt': 0.0,
#    'desc': None,
#    'disbursementMethod': 'CASH',
#    'dti': 15.72,
#    'dtiJoint': None,
#    'earliestCrLine': '2008-03-11T17:00:00.000-07:00',
#    'empLength': 36,
#    'empTitle': 'Counselor',
#    'expD': '2018-06-11T14:00:00.000-07:00',
#    'expDefaultRate': 3.95,
#    'ficoRangeHigh': 664,
#    'ficoRangeLow': 660,
#    'fundedAmount': 2250.0,
#    'grade': 'B',
#    'homeOwnership': 'RENT',
#    'housingPayment': 425.0,
#    'iLUtil': 97.7,
#    'id': 133350983,
#    'ilsExpD': '2018-05-12T14:00:00.000-07:00',
#    'initialListStatus': 'F',
#    'inqFi': 6,
#    'inqLast12m': 3,
#    'inqLast6Mths': 1,
#    'installment': 173.04,
#    'intRate': 12.13,
#    'investorCount': None,
#    'isIncV': 'NOT_VERIFIED',
#    'isIncVJoint': None,
#    'listD': '2018-05-12T14:00:00.000-07:00',
#    'loanAmount': 5200.0,
#    'maxBalBc': 1605.0,
#    'memberId': 150320965,
#    'moSinOldIlAcct': 91,
#    'moSinOldRevTlOp': 61,
#    'moSinRcntRevTlOp': 4,
#    'moSinRcntTl': 4,
#    'mortAcc': 0,
#    'mtgPayment': 0.0,
#    'mthsSinceLastDelinq': None,
#    'mthsSinceLastMajorDerog': None,
#    'mthsSinceLastRecord': None,
#    'mthsSinceRcntIl': 12,
#    'mthsSinceRecentBc': 4,
#    'mthsSinceRecentBcDlq': None,
#    'mthsSinceRecentInq': 6,
#    'mthsSinceRecentRevolDelinq': None,
#    'numAcctsEver120Ppd': 0,
#    'numActvBcTl': 4,
#    'numActvRevTl': 5,
#    'numBcSats': 4,
#    'numBcTl': 5,
#    'numIlTl': 6,
#    'numOpRevTl': 6,
#    'numRevAccts': 8,
#    'numRevTlBalGt0': 5,
#    'numSats': 9,
#    'numTl120dpd2m': 0,
#    'numTl30dpd': 0,
#    'numTl90gDpd24m': 0,
#    'numTlOpPast12m': 5,
#    'openAcc': 9,
#    'openAcc6m': 4,
#    'openActIl': 2,
#    'openIl12m': 1,
#    'openIl24m': 2,
#    'openRv12m': 4,
#    'openRv24m': 5,
#    'pctTlNvrDlq': 100,
#    'percentBcGt75': 75.0,
#    'pubRec': 0,
#    'pubRecBankruptcies': 0,
#    'purpose': 'credit_card',
#    'reviewStatus': 'APPROVED',
#    'reviewStatusD': '2018-05-12T12:59:33.000-07:00',
#    'revolBal': 4760.0,
#    'revolBalJoint': None,
#    'revolUtil': 54.7,
#    'secAppChargeoffWithin12Mths': None,
#    'secAppCollections12MthsExMed': None,
#    'secAppEarliestCrLine': None,
#    'secAppFicoRangeHigh': None,
#    'secAppFicoRangeLow': None,
#    'secAppInqLast6Mths': None,
#    'secAppMortAcc': None,
#    'secAppMthsSinceLastMajorDerog': None,
#    'secAppNumRevAccts': None,
#    'secAppOpenAcc': None,
#    'secAppOpenActIl': None,
#    'secAppRevolUtil': None,
#    'serviceFeeRate': 0.97,
#    'subGrade': 'B5',
#    'taxLiens': 0,
#    'term': 36,
#    'totCollAmt': 3174,
#    'totCurBal': 43882,
#    'totHiCredLim': 48729,
#    'totalAcc': 15,
#    'totalBalExMort': 43882,
#    'totalBalIl': 38922.0,
#    'totalBcLimit': 7900,
#    'totalCuTl': 1,
#    'totalIlHighCreditLimit': 39829,
#    'totalRevHiLim': 8700},
#   {'accNowDelinq': 0,
#    'accOpenPast24Mths': 2,
#    'acceptD': '2018-05-09T16:11:02.000-07:00',
#    'addrState': 'FL',
#    'addrZip': '331xx',
#    'allUtil': 39.3,
#    'annualInc': 40000.0,
#    'annualIncJoint': None,
#    'applicationType': 'INDIVIDUAL',
#    'avgCurBal': 1242,
#    'bcOpenToBuy': 782,
#    'bcUtil': 86.5,
#    'chargeoffWithin12Mths': 0,
#    'collections12MthsExMed': 0,
#    'creditPullD': '2018-05-05T14:06:19.000-07:00',
#    'delinq2Yrs': 0,
#    'delinqAmnt': 0.0,
#    'desc': None,
#    'disbursementMethod': 'CASH',
#    'dti': 17.28,
#    'dtiJoint': None,
#    'earliestCrLine': '2015-02-04T16:00:00.000-08:00',
#    'empLength': 24,
#    'empTitle': 'Bartender',
#    'expD': '2018-06-11T14:00:00.000-07:00',
#    'expDefaultRate': 7.4,
#    'ficoRangeHigh': 689,
#    'ficoRangeLow': 685,
#    'fundedAmount': 3800.0,
#    'grade': 'C',
#    'homeOwnership': 'RENT',
#    'housingPayment': 200.0,
#    'iLUtil': 2.8,
#    'id': 132870068,
#    'ilsExpD': '2018-05-12T14:00:00.000-07:00',
#    'initialListStatus': 'F',
#    'inqFi': 0,
#    'inqLast12m': 0,
#    'inqLast6Mths': 0,
#    'installment': 247.7,
#    'intRate': 16.46,
#    'investorCount': None,
#    'isIncV': 'SOURCE_VERIFIED',
#    'isIncVJoint': None,
#    'listD': '2018-05-12T14:00:00.000-07:00',
#    'loanAmount': 7000.0,
#    'maxBalBc': 2484.0,
#    'memberId': 149674309,
#    'moSinOldIlAcct': 36,
#    'moSinOldRevTlOp': 39,
#    'moSinRcntRevTlOp': 10,
#    'moSinRcntTl': 10,
#    'mortAcc': 0,
#    'mtgPayment': 0.0,
#    'mthsSinceLastDelinq': None,
#    'mthsSinceLastMajorDerog': None,
#    'mthsSinceLastRecord': None,
#    'mthsSinceRcntIl': 36,
#    'mthsSinceRecentBc': 10,
#    'mthsSinceRecentBcDlq': None,
#    'mthsSinceRecentInq': None,
#    'mthsSinceRecentRevolDelinq': None,
#    'numAcctsEver120Ppd': 0,
#    'numActvBcTl': 3,
#    'numActvRevTl': 5,
#    'numBcSats': 3,
#    'numBcTl': 3,
#    'numIlTl': 1,
#    'numOpRevTl': 5,
#    'numRevAccts': 5,
#    'numRevTlBalGt0': 5,
#    'numSats': 6,
#    'numTl120dpd2m': 0,
#    'numTl30dpd': 0,
#    'numTl90gDpd24m': 0,
#    'numTlOpPast12m': 1,
#    'openAcc': 6,
#    'openAcc6m': 0,
#    'openActIl': 1,
#    'openIl12m': 0,
#    'openIl24m': 0,
#    'openRv12m': 1,
#    'openRv24m': 2,
#    'pctTlNvrDlq': 100,
#    'percentBcGt75': 100.0,
#    'pubRec': 0,
#    'pubRecBankruptcies': 0,
#    'purpose': 'debt_consolidation',
#    'reviewStatus': 'APPROVED',
#    'reviewStatusD': '2018-05-12T13:13:41.000-07:00',
#    'revolBal': 7168.0,
#    'revolBalJoint': None,
#    'revolUtil': 82.4,
#    'secAppChargeoffWithin12Mths': None,
#    'secAppCollections12MthsExMed': None,
#    'secAppEarliestCrLine': None,
#    'secAppFicoRangeHigh': None,
#    'secAppFicoRangeLow': None,
#    'secAppInqLast6Mths': None,
#    'secAppMortAcc': None,
#    'secAppMthsSinceLastMajorDerog': None,
#    'secAppNumRevAccts': None,
#    'secAppOpenAcc': None,
#    'secAppOpenActIl': None,
#    'secAppRevolUtil': None,
#    'serviceFeeRate': 1.15,
#    'subGrade': 'C5',
#    'taxLiens': 0,
#    'term': 36,
#    'totCollAmt': 0,
#    'totCurBal': 7452,
#    'totHiCredLim': 18943,
#    'totalAcc': 6,
#    'totalBalExMort': 7452,
#    'totalBalIl': 284.0,
#    'totalBcLimit': 5800,
#    'totalCuTl': 0,
#    'totalIlHighCreditLimit': 10243,
#    'totalRevHiLim': 8700},
#   {'accNowDelinq': 0,
#    'accOpenPast24Mths': 5,
#    'acceptD': '2018-05-12T13:22:41.000-07:00',
#    'addrState': 'CA',
#    'addrZip': '920xx',
#    'allUtil': 32.9,
#    'annualInc': 39000.0,
#    'annualIncJoint': None,
#    'applicationType': 'INDIVIDUAL',
#    'avgCurBal': 493,
#    'bcOpenToBuy': 3535,
#    'bcUtil': 21.4,
#    'chargeoffWithin12Mths': 0,
#    'collections12MthsExMed': 0,
#    'creditPullD': '2018-05-12T13:10:40.000-07:00',
#    'delinq2Yrs': 0,
#    'delinqAmnt': 0.0,
#    'desc': None,
#    'disbursementMethod': 'CASH',
#    'dti': 5.45,
#    'dtiJoint': None,
#    'earliestCrLine': '2007-04-11T17:00:00.000-07:00',
#    'empLength': 24,
#    'empTitle': 'Coach operator ',
#    'expD': '2018-06-11T14:00:00.000-07:00',
#    'expDefaultRate': 7.4,
#    'ficoRangeHigh': 664,
#    'ficoRangeLow': 660,
#    'fundedAmount': 2250.0,
#    'grade': 'C',
#    'homeOwnership': 'OWN',
#    'housingPayment': None,
#    'iLUtil': None,
#    'id': 133351028,
#    'ilsExpD': '2018-05-12T14:00:00.000-07:00',
#    'initialListStatus': 'F',
#    'inqFi': 3,
#    'inqLast12m': 3,
#    'inqLast6Mths': 1,
#    'installment': 212.31,
#    'intRate': 16.46,
#    'investorCount': None,
#    'isIncV': 'SOURCE_VERIFIED',
#    'isIncVJoint': None,
#    'listD': '2018-05-12T14:00:00.000-07:00',
#    'loanAmount': 6000.0,
#    'maxBalBc': 790.0,
#    'memberId': 150321013,
#    'moSinOldIlAcct': 133,
#    'moSinOldRevTlOp': 17,
#    'moSinRcntRevTlOp': 8,
#    'moSinRcntTl': 3,
#    'mortAcc': 0,
#    'mtgPayment': 0.0,
#    'mthsSinceLastDelinq': 69,
#    'mthsSinceLastMajorDerog': 69,
#    'mthsSinceLastRecord': None,
#    'mthsSinceRcntIl': 3,
#    'mthsSinceRecentBc': 8,
#    'mthsSinceRecentBcDlq': None,
#    'mthsSinceRecentInq': 3,
#    'mthsSinceRecentRevolDelinq': None,
#    'numAcctsEver120Ppd': 1,
#    'numActvBcTl': 2,
#    'numActvRevTl': 4,
#    'numBcSats': 2,
#    'numBcTl': 2,
#    'numIlTl': 2,
#    'numOpRevTl': 4,
#    'numRevAccts': 4,
#    'numRevTlBalGt0': 4,
#    'numSats': 4,
#    'numTl120dpd2m': 0,
#    'numTl30dpd': 0,
#    'numTl90gDpd24m': 0,
#    'numTlOpPast12m': 3,
#    'openAcc': 4,
#    'openAcc6m': 1,
#    'openActIl': 0,
#    'openIl12m': 1,
#    'openIl24m': 1,
#    'openRv12m': 2,
#    'openRv24m': 4,
#    'pctTlNvrDlq': 83,
#    'percentBcGt75': 0.0,
#    'pubRec': 0,
#    'pubRecBankruptcies': 0,
#    'purpose': 'credit_card',
#    'reviewStatus': 'APPROVED',
#    'reviewStatusD': '2018-05-12T13:24:21.000-07:00',
#    'revolBal': 1972.0,
#    'revolBalJoint': None,
#    'revolUtil': 32.9,
#    'secAppChargeoffWithin12Mths': None,
#    'secAppCollections12MthsExMed': None,
#    'secAppEarliestCrLine': None,
#    'secAppFicoRangeHigh': None,
#    'secAppFicoRangeLow': None,
#    'secAppInqLast6Mths': None,
#    'secAppMortAcc': None,
#    'secAppMthsSinceLastMajorDerog': None,
#    'secAppNumRevAccts': None,
#    'secAppOpenAcc': None,
#    'secAppOpenActIl': None,
#    'secAppRevolUtil': None,
#    'serviceFeeRate': 1.15,
#    'subGrade': 'C5',
#    'taxLiens': 0,
#    'term': 36,
#    'totCollAmt': 0,
#    'totCurBal': 1972,
#    'totHiCredLim': 6000,
#    'totalAcc': 6,
#    'totalBalExMort': 1972,
#    'totalBalIl': 0.0,
#    'totalBcLimit': 4500,
#    'totalCuTl': 1,
#    'totalIlHighCreditLimit': 0,
#    'totalRevHiLim': 6000},
#   {'accNowDelinq': 0,
#    'accOpenPast24Mths': 7,
#    'acceptD': '2018-05-10T18:26:21.000-07:00',
#    'addrState': 'AZ',
#    'addrZip': '852xx',
#    'allUtil': 51.7,
#    'annualInc': 40000.0,
#    'annualIncJoint': None,
#    'applicationType': 'INDIVIDUAL',
#    'avgCurBal': 12899,
#    'bcOpenToBuy': 5580,
#    'bcUtil': 74.9,
#    'chargeoffWithin12Mths': 0,
#    'collections12MthsExMed': 0,
#    'creditPullD': '2018-04-24T16:42:16.000-07:00',
#    'delinq2Yrs': 0,
#    'delinqAmnt': 0.0,
#    'desc': None,
#    'disbursementMethod': 'CASH',
#    'dti': 39.09,
#    'dtiJoint': None,
#    'earliestCrLine': '2003-09-23T17:00:00.000-07:00',
#    'empLength': None,
#    'empTitle': None,
#    'expD': '2018-06-11T14:00:00.000-07:00',
#    'expDefaultRate': 6.8,
#    'ficoRangeHigh': 664,
#    'ficoRangeLow': 660,
#    'fundedAmount': 800.0,
#    'grade': 'C',
#    'homeOwnership': 'MORTGAGE',
#    'housingPayment': 430.0,
#    'iLUtil': 53.7,
#    'id': 132215642,
#    'ilsExpD': '2018-05-12T14:00:00.000-07:00',
#    'initialListStatus': 'F',
#    'inqFi': 0,
#    'inqLast12m': 4,
#    'inqLast6Mths': 2,
#    'installment': 199.55,
#    'intRate': 16.01,
#    'investorCount': None,
#    'isIncV': 'VERIFIED',
#    'isIncVJoint': None,
#    'listD': '2018-05-12T14:00:00.000-07:00',
#    'loanAmount': 5675.0,
#    'maxBalBc': 4725.0,
#    'memberId': 148387395,
#    'moSinOldIlAcct': 158,
#    'moSinOldRevTlOp': 161,
#    'moSinRcntRevTlOp': 3,
#    'moSinRcntTl': 3,
#    'mortAcc': 1,
#    'mtgPayment': 547.0,
#    'mthsSinceLastDelinq': None,
#    'mthsSinceLastMajorDerog': None,
#    'mthsSinceLastRecord': 107,
#    'mthsSinceRcntIl': 28,
#    'mthsSinceRecentBc': 3,
#    'mthsSinceRecentBcDlq': None,
#    'mthsSinceRecentInq': 3,
#    'mthsSinceRecentRevolDelinq': None,
#    'numAcctsEver120Ppd': 0,
#    'numActvBcTl': 7,
#    'numActvRevTl': 10,
#    'numBcSats': 7,
#    'numBcTl': 14,
#    'numIlTl': 6,
#    'numOpRevTl': 16,
#    'numRevAccts': 30,
#    'numRevTlBalGt0': 10,
#    'numSats': 20,
#    'numTl120dpd2m': 0,
#    'numTl30dpd': 0,
#    'numTl90gDpd24m': 0,
#    'numTlOpPast12m': 3,
#    'openAcc': 21,
#    'openAcc6m': 3,
#    'openActIl': 4,
#    'openIl12m': 0,
#    'openIl24m': 0,
#    'openRv12m': 3,
#    'openRv24m': 7,
#    'pctTlNvrDlq': 100,
#    'percentBcGt75': 71.4,
#    'pubRec': 1,
#    'pubRecBankruptcies': 1,
#    'purpose': 'debt_consolidation',
#    'reviewStatus': 'APPROVED',
#    'reviewStatusD': '2018-05-12T13:10:55.000-07:00',
#    'revolBal': 19152.0,
#    'revolBalJoint': None,
#    'revolUtil': 49.9,
#    'secAppChargeoffWithin12Mths': None,
#    'secAppCollections12MthsExMed': None,
#    'secAppEarliestCrLine': None,
#    'secAppFicoRangeHigh': None,
#    'secAppFicoRangeLow': None,
#    'secAppInqLast6Mths': None,
#    'secAppMortAcc': None,
#    'secAppMthsSinceLastMajorDerog': None,
#    'secAppNumRevAccts': None,
#    'secAppOpenAcc': None,
#    'secAppOpenActIl': None,
#    'secAppRevolUtil': None,
#    'serviceFeeRate': 1.13,
#    'subGrade': 'C5',
#    'taxLiens': 0,
#    'term': 36,
#    'totCollAmt': 0,
#    'totCurBal': 270871,
#    'totHiCredLim': 238550,
#    'totalAcc': 37,
#    'totalBalExMort': 244128,
#    'totalBalIl': 224976.0,
#    'totalBcLimit': 22200,
#    'totalCuTl': 2,
#    'totalIlHighCreditLimit': 165150,
#    'totalRevHiLim': 38400},
#   {'accNowDelinq': 0,
#    'accOpenPast24Mths': 6,
#    'acceptD': '2018-05-12T12:52:51.000-07:00',
#    'addrState': 'PA',
#    'addrZip': '191xx',
#    'allUtil': 70.1,
#    'annualInc': 78000.0,
#    'annualIncJoint': None,
#    'applicationType': 'INDIVIDUAL',
#    'avgCurBal': 2065,
#    'bcOpenToBuy': 4407,
#    'bcUtil': 67.1,
#    'chargeoffWithin12Mths': 0,
#    'collections12MthsExMed': 0,
#    'creditPullD': '2018-05-12T12:41:05.000-07:00',
#    'delinq2Yrs': 0,
#    'delinqAmnt': 0.0,
#    'desc': None,
#    'disbursementMethod': 'CASH',
#    'dti': 10.58,
#    'dtiJoint': None,
#    'earliestCrLine': '2009-04-11T17:00:00.000-07:00',
#    'empLength': 84,
#    'empTitle': 'Transit operator',
#    'expD': '2018-06-11T14:00:00.000-07:00',
#    'expDefaultRate': 3.95,
#    'ficoRangeHigh': 679,
#    'ficoRangeLow': 675,
#    'fundedAmount': 5050.0,
#    'grade': 'B',
#    'homeOwnership': 'RENT',
#    'housingPayment': 0.0,
#    'iLUtil': 81.8,
#    'id': 133353846,
#    'ilsExpD': '2018-05-12T14:00:00.000-07:00',
#    'initialListStatus': 'F',
#    'inqFi': 0,
#    'inqLast12m': 1,
#    'inqLast6Mths': 0,
#    'installment': 332.77,
#    'intRate': 12.13,
#    'investorCount': None,
#    'isIncV': 'NOT_VERIFIED',
#    'isIncVJoint': None,
#    'listD': '2018-05-12T14:00:00.000-07:00',
#    'loanAmount': 10000.0,
#    'maxBalBc': 3988.0,
#    'memberId': 150316789,
#    'moSinOldIlAcct': 109,
#    'moSinOldRevTlOp': 50,
#    'moSinRcntRevTlOp': 8,
#    'moSinRcntTl': 8,
#    'mortAcc': 0,
#    'mtgPayment': 0.0,
#    'mthsSinceLastDelinq': 31,
#    'mthsSinceLastMajorDerog': 31,
#    'mthsSinceLastRecord': None,
#    'mthsSinceRcntIl': 32,
#    'mthsSinceRecentBc': 8,
#    'mthsSinceRecentBcDlq': None,
#    'mthsSinceRecentInq': 8,
#    'mthsSinceRecentRevolDelinq': None,
#    'numAcctsEver120Ppd': 3,
#    'numActvBcTl': 5,
#    'numActvRevTl': 8,
#    'numBcSats': 6,
#    'numBcTl': 6,
#    'numIlTl': 6,
#    'numOpRevTl': 9,
#    'numRevAccts': 10,
#    'numRevTlBalGt0': 8,
#    'numSats': 13,
#    'numTl120dpd2m': 0,
#    'numTl30dpd': 0,
#    'numTl90gDpd24m': 0,
#    'numTlOpPast12m': 2,
#    'openAcc': 13,
#    'openAcc6m': 0,
#    'openActIl': 4,
#    'openIl12m': 0,
#    'openIl24m': 0,
#    'openRv12m': 2,
#    'openRv24m': 6,
#    'pctTlNvrDlq': 86,
#    'percentBcGt75': 20.0,
#    'pubRec': 0,
#    'pubRecBankruptcies': 0,
#    'purpose': 'credit_card',
#    'reviewStatus': 'APPROVED',
#    'reviewStatusD': '2018-05-12T13:00:56.000-07:00',
#    'revolBal': 9506.0,
#    'revolBalJoint': None,
#    'revolUtil': 56.9,
#    'secAppChargeoffWithin12Mths': None,
#    'secAppCollections12MthsExMed': None,
#    'secAppEarliestCrLine': None,
#    'secAppFicoRangeHigh': None,
#    'secAppFicoRangeLow': None,
#    'secAppInqLast6Mths': None,
#    'secAppMortAcc': None,
#    'secAppMthsSinceLastMajorDerog': None,
#    'secAppNumRevAccts': None,
#    'secAppOpenAcc': None,
#    'secAppOpenActIl': None,
#    'secAppRevolUtil': None,
#    'serviceFeeRate': 0.97,
#    'subGrade': 'B5',
#    'taxLiens': 0,
#    'term': 36,
#    'totCollAmt': 0,
#    'totCurBal': 24775,
#    'totHiCredLim': 35365,
#    'totalAcc': 16,
#    'totalBalExMort': 24775,
#    'totalBalIl': 15269.0,
#    'totalBcLimit': 13400,
#    'totalCuTl': 0,
#    'totalIlHighCreditLimit': 18665,
#    'totalRevHiLim': 16700},
#   {'accNowDelinq': 0,
#    'accOpenPast24Mths': 2,
#    'acceptD': '2018-05-11T11:40:50.000-07:00',
#    'addrState': 'CO',
#    'addrZip': '800xx',
#    'allUtil': 81.8,
#    'annualInc': 69000.0,
#    'annualIncJoint': None,
#    'applicationType': 'INDIVIDUAL',
#    'avgCurBal': 42718,
#    'bcOpenToBuy': 2572,
#    'bcUtil': 81.8,
#    'chargeoffWithin12Mths': 0,
#    'collections12MthsExMed': 0,
#    'creditPullD': '2018-05-11T11:32:42.000-07:00',
#    'delinq2Yrs': 0,
#    'delinqAmnt': 0.0,
#    'desc': None,
#    'disbursementMethod': 'CASH',
#    'dti': 10.52,
#    'dtiJoint': None,
#    'earliestCrLine': '2004-08-10T17:00:00.000-07:00',
#    'empLength': 108,
#    'empTitle': 'Foreman',
#    'expD': '2018-06-11T14:00:00.000-07:00',
#    'expDefaultRate': 3.95,
#    'ficoRangeHigh': 679,
#    'ficoRangeLow': 675,
#    'fundedAmount': 6475.0,
#    'grade': 'B',
#    'homeOwnership': 'MORTGAGE',
#    'housingPayment': 1236.0,
#    'iLUtil': None,
#    'id': 133307082,
#    'ilsExpD': '2018-05-12T14:00:00.000-07:00',
#    'initialListStatus': 'F',
#    'inqFi': 0,
#    'inqLast12m': 0,
#    'inqLast6Mths': 0,
#    'installment': 399.32,
#    'intRate': 12.13,
#    'investorCount': None,
#    'isIncV': 'SOURCE_VERIFIED',
#    'isIncVJoint': None,
#    'listD': '2018-05-12T14:00:00.000-07:00',
#    'loanAmount': 12000.0,
#    'maxBalBc': 6141.0,
#    'memberId': 150268902,
#    'moSinOldIlAcct': 136,
#    'moSinOldRevTlOp': 165,
#    'moSinRcntRevTlOp': 38,
#    'moSinRcntTl': 13,
#    'mortAcc': 2,
#    'mtgPayment': 1250.05,
#    'mthsSinceLastDelinq': 48,
#    'mthsSinceLastMajorDerog': 48,
#    'mthsSinceLastRecord': None,
#    'mthsSinceRcntIl': 22,
#    'mthsSinceRecentBc': 38,
#    'mthsSinceRecentBcDlq': None,
#    'mthsSinceRecentInq': None,
#    'mthsSinceRecentRevolDelinq': None,
#    'numAcctsEver120Ppd': 2,
#    'numActvBcTl': 4,
#    'numActvRevTl': 4,
#    'numBcSats': 4,
#    'numBcTl': 4,
#    'numIlTl': 2,
#    'numOpRevTl': 4,
#    'numRevAccts': 4,
#    'numRevTlBalGt0': 4,
#    'numSats': 5,
#    'numTl120dpd2m': 0,
#    'numTl30dpd': 0,
#    'numTl90gDpd24m': 0,
#    'numTlOpPast12m': 0,
#    'openAcc': 5,
#    'openAcc6m': 0,
#    'openActIl': 0,
#    'openIl12m': 0,
#    'openIl24m': 1,
#    'openRv12m': 0,
#    'openRv24m': 0,
#    'pctTlNvrDlq': 75,
#    'percentBcGt75': 25.0,
#    'pubRec': 0,
#    'pubRecBankruptcies': 0,
#    'purpose': 'home_improvement',
#    'reviewStatus': 'APPROVED',
#    'reviewStatusD': '2018-05-12T10:58:52.000-07:00',
#    'revolBal': 11528.0,
#    'revolBalJoint': None,
#    'revolUtil': 81.8,
#    'secAppChargeoffWithin12Mths': None,
#    'secAppCollections12MthsExMed': None,
#    'secAppEarliestCrLine': None,
#    'secAppFicoRangeHigh': None,
#    'secAppFicoRangeLow': None,
#    'secAppInqLast6Mths': None,
#    'secAppMortAcc': None,
#    'secAppMthsSinceLastMajorDerog': None,
#    'secAppNumRevAccts': None,
#    'secAppOpenAcc': None,
#    'secAppOpenActIl': None,
#    'secAppRevolUtil': None,
#    'serviceFeeRate': 0.97,
#    'subGrade': 'B5',
#    'taxLiens': 0,
#    'term': 36,
#    'totCollAmt': 68,
#    'totCurBal': 213589,
#    'totHiCredLim': 221100,
#    'totalAcc': 8,
#    'totalBalExMort': 11528,
#    'totalBalIl': 0.0,
#    'totalBcLimit': 14100,
#    'totalCuTl': 0,
#    'totalIlHighCreditLimit': 0,
#    'totalRevHiLim': 14100},
#   {'accNowDelinq': 0,
#    'accOpenPast24Mths': 3,
#    'acceptD': '2018-05-12T10:04:53.000-07:00',
#    'addrState': 'CA',
#    'addrZip': '920xx',
#    'allUtil': 59.3,
#    'annualInc': 39250.0,
#    'annualIncJoint': None,
#    'applicationType': 'INDIVIDUAL',
#    'avgCurBal': 3243,
#    'bcOpenToBuy': 22266,
#    'bcUtil': 19.6,
#    'chargeoffWithin12Mths': 0,
#    'collections12MthsExMed': 0,
#    'creditPullD': '2018-04-23T22:09:56.000-07:00',
#    'delinq2Yrs': 0,
#    'delinqAmnt': 0.0,
#    'desc': None,
#    'disbursementMethod': 'CASH',
#    'dti': 28.44,
#    'dtiJoint': None,
#    'earliestCrLine': '2006-09-23T17:00:00.000-07:00',
#    'empLength': 0,
#    'empTitle': 'Drafter',
#    'expD': '2018-06-11T14:00:00.000-07:00',
#    'expDefaultRate': 1.86,
#    'ficoRangeHigh': 769,
#    'ficoRangeLow': 765,
#    'fundedAmount': 3000.0,
#    'grade': 'A',
#    'homeOwnership': 'RENT',
#    'housingPayment': 600.0,
#    'iLUtil': 96.2,
#    'id': 132150897,
#    'ilsExpD': '2018-05-12T14:00:00.000-07:00',
#    'initialListStatus': 'F',
#    'inqFi': 0,
#    'inqLast12m': 0,
#    'inqLast6Mths': 0,
#    'installment': 274.09,
#    'intRate': 6.07,
#    'investorCount': None,
#    'isIncV': 'NOT_VERIFIED',
#    'isIncVJoint': None,
#    'listD': '2018-05-12T14:00:00.000-07:00',
#    'loanAmount': 9000.0,
#    'maxBalBc': 2217.0,
#    'memberId': 148316115,
#    'moSinOldIlAcct': 139,
#    'moSinOldRevTlOp': 81,
#    'moSinRcntRevTlOp': 14,
#    'moSinRcntTl': 3,
#    'mortAcc': 0,
#    'mtgPayment': 0.0,
#    'mthsSinceLastDelinq': None,
#    'mthsSinceLastMajorDerog': None,
#    'mthsSinceLastRecord': None,
#    'mthsSinceRcntIl': 3,
#    'mthsSinceRecentBc': 48,
#    'mthsSinceRecentBcDlq': None,
#    'mthsSinceRecentInq': 22,
#    'mthsSinceRecentRevolDelinq': None,
#    'numAcctsEver120Ppd': 0,
#    'numActvBcTl': 4,
#    'numActvRevTl': 5,
#    'numBcSats': 4,
#    'numBcTl': 4,
#    'numIlTl': 19,
#    'numOpRevTl': 5,
#    'numRevAccts': 6,
#    'numRevTlBalGt0': 5,
#    'numSats': 14,
#    'numTl120dpd2m': 0,
#    'numTl30dpd': 0,
#    'numTl90gDpd24m': 0,
#    'numTlOpPast12m': 1,
#    'openAcc': 14,
#    'openAcc6m': 1,
#    'openActIl': 9,
#    'openIl12m': 1,
#    'openIl24m': 1,
#    'openRv12m': 0,
#    'openRv24m': 2,
#    'pctTlNvrDlq': 100,
#    'percentBcGt75': 0.0,
#    'pubRec': 0,
#    'pubRecBankruptcies': 0,
#    'purpose': 'debt_consolidation',
#    'reviewStatus': 'APPROVED',
#    'reviewStatusD': '2018-05-12T10:07:28.000-07:00',
#    'revolBal': 5681.0,
#    'revolBalJoint': None,
#    'revolUtil': 16.1,
#    'secAppChargeoffWithin12Mths': None,
#    'secAppCollections12MthsExMed': None,
#    'secAppEarliestCrLine': None,
#    'secAppFicoRangeHigh': None,
#    'secAppFicoRangeLow': None,
#    'secAppInqLast6Mths': None,
#    'secAppMortAcc': None,
#    'secAppMthsSinceLastMajorDerog': None,
#    'secAppNumRevAccts': None,
#    'secAppOpenAcc': None,
#    'secAppOpenActIl': None,
#    'secAppRevolUtil': None,
#    'serviceFeeRate': 0.83,
#    'subGrade': 'A2',
#    'taxLiens': 0,
#    'term': 36,
#    'totCollAmt': 0,
#    'totCurBal': 45396,
#    'totHiCredLim': 76576,
#    'totalAcc': 25,
#    'totalBalExMort': 45396,
#    'totalBalIl': 39715.0,
#    'totalBcLimit': 27700,
#    'totalCuTl': 0,
#    'totalIlHighCreditLimit': 41276,
#    'totalRevHiLim': 35300},
#   {'accNowDelinq': 0,
#    'accOpenPast24Mths': 3,
#    'acceptD': '2018-05-12T12:38:16.000-07:00',
#    'addrState': 'AZ',
#    'addrZip': '852xx',
#    'allUtil': 49.5,
#    'annualInc': 60000.0,
#    'annualIncJoint': None,
#    'applicationType': 'INDIVIDUAL',
#    'avgCurBal': 2771,
#    'bcOpenToBuy': 31036,
#    'bcUtil': 46.3,
#    'chargeoffWithin12Mths': 0,
#    'collections12MthsExMed': 0,
#    'creditPullD': '2018-05-12T12:01:29.000-07:00',
#    'delinq2Yrs': 0,
#    'delinqAmnt': 0.0,
#    'desc': None,
#    'disbursementMethod': 'CASH',
#    'dti': 21.84,
#    'dtiJoint': None,
#    'earliestCrLine': '1996-08-11T17:00:00.000-07:00',
#    'empLength': 120,
#    'empTitle': 'Web Specialist',
#    'expD': '2018-06-11T14:00:00.000-07:00',
#    'expDefaultRate': 3.95,
#    'ficoRangeHigh': 689,
#    'ficoRangeLow': 685,
#    'fundedAmount': 5825.0,
#    'grade': 'B',
#    'homeOwnership': 'RENT',
#    'housingPayment': 1100.0,
#    'iLUtil': 61.7,
#    'id': 133343935,
#    'ilsExpD': '2018-05-12T14:00:00.000-07:00',
#    'initialListStatus': 'F',
#    'inqFi': 0,
#    'inqLast12m': 3,
#    'inqLast6Mths': 0,
#    'installment': 384.85,
#    'intRate': 9.58,
#    'investorCount': None,
#    'isIncV': 'NOT_VERIFIED',
#    'isIncVJoint': None,
#    'listD': '2018-05-12T14:00:00.000-07:00',
#    'loanAmount': 12000.0,
#    'maxBalBc': 10322.0,
#    'memberId': 150317927,
#    'moSinOldIlAcct': 261,
#    'moSinOldRevTlOp': 255,
#    'moSinRcntRevTlOp': 10,
#    'moSinRcntTl': 10,
#    'mortAcc': 0,
#    'mtgPayment': 0.0,
#    'mthsSinceLastDelinq': None,
#    'mthsSinceLastMajorDerog': None,
#    'mthsSinceLastRecord': None,
#    'mthsSinceRcntIl': 10,
#    'mthsSinceRecentBc': 10,
#    'mthsSinceRecentBcDlq': None,
#    'mthsSinceRecentInq': 10,
#    'mthsSinceRecentRevolDelinq': None,
#    'numAcctsEver120Ppd': 0,
#    'numActvBcTl': 10,
#    'numActvRevTl': 10,
#    'numBcSats': 11,
#    'numBcTl': 12,
#    'numIlTl': 6,
#    'numOpRevTl': 11,
#    'numRevAccts': 13,
#    'numRevTlBalGt0': 10,
#    'numSats': 13,
#    'numTl120dpd2m': 0,
#    'numTl30dpd': 0,
#    'numTl90gDpd24m': 0,
#    'numTlOpPast12m': 3,
#    'openAcc': 13,
#    'openAcc6m': 0,
#    'openActIl': 2,
#    'openIl12m': 1,
#    'openIl24m': 1,
#    'openRv12m': 2,
#    'openRv24m': 2,
#    'pctTlNvrDlq': 100,
#    'percentBcGt75': 63.6,
#    'pubRec': 0,
#    'pubRecBankruptcies': 0,
#    'purpose': 'credit_card',
#    'reviewStatus': 'APPROVED',
#    'reviewStatusD': '2018-05-12T12:41:24.000-07:00',
#    'revolBal': 26764.0,
#    'revolBalJoint': None,
#    'revolUtil': 46.3,
#    'secAppChargeoffWithin12Mths': None,
#    'secAppCollections12MthsExMed': None,
#    'secAppEarliestCrLine': None,
#    'secAppFicoRangeHigh': None,
#    'secAppFicoRangeLow': None,
#    'secAppInqLast6Mths': None,
#    'secAppMortAcc': None,
#    'secAppMthsSinceLastMajorDerog': None,
#    'secAppNumRevAccts': None,
#    'secAppOpenAcc': None,
#    'secAppOpenActIl': None,
#    'secAppRevolUtil': None,
#    'serviceFeeRate': 0.97,
#    'subGrade': 'B1',
#    'taxLiens': 0,
#    'term': 36,
#    'totCollAmt': 0,
#    'totCurBal': 36023,
#    'totHiCredLim': 72800,
#    'totalAcc': 19,
#    'totalBalExMort': 36023,
#    'totalBalIl': 9259.0,
#    'totalBcLimit': 57800,
#    'totalCuTl': 0,
#    'totalIlHighCreditLimit': 15000,
#    'totalRevHiLim': 57800},
#   {'accNowDelinq': 0,
#    'accOpenPast24Mths': 3,
#    'acceptD': '2018-05-10T21:08:08.000-07:00',
#    'addrState': 'HI',
#    'addrZip': '968xx',
#    'allUtil': 63.9,
#    'annualInc': 62000.0,
#    'annualIncJoint': None,
#    'applicationType': 'INDIVIDUAL',
#    'avgCurBal': 5605,
#    'bcOpenToBuy': 13524,
#    'bcUtil': 51.0,
#    'chargeoffWithin12Mths': 0,
#    'collections12MthsExMed': 0,
#    'creditPullD': '2018-05-10T21:01:34.000-07:00',
#    'delinq2Yrs': 0,
#    'delinqAmnt': 0.0,
#    'desc': None,
#    'disbursementMethod': 'DIRECT_PAY',
#    'dti': 17.73,
#    'dtiJoint': None,
#    'earliestCrLine': '1996-01-10T16:00:00.000-08:00',
#    'empLength': 12,
#    'empTitle': 'Manager ',
#    'expD': '2018-06-11T14:00:00.000-07:00',
#    'expDefaultRate': 1.88,
#    'ficoRangeHigh': 729,
#    'ficoRangeLow': 725,
#    'fundedAmount': 3475.0,
#    'grade': 'A',
#    'homeOwnership': 'RENT',
#    'housingPayment': 1700.0,
#    'iLUtil': 78.2,
#    'id': 133282963,
#    'ilsExpD': '2018-05-12T14:00:00.000-07:00',
#    'initialListStatus': 'F',
#    'inqFi': 0,
#    'inqLast12m': 1,
#    'inqLast6Mths': 0,
#    'installment': 301.11,
#    'intRate': 5.31,
#    'investorCount': None,
#    'isIncV': 'NOT_VERIFIED',
#    'isIncVJoint': None,
#    'listD': '2018-05-12T14:00:00.000-07:00',
#    'loanAmount': 10000.0,
#    'maxBalBc': 7495.0,
#    'memberId': 150243109,
#    'moSinOldIlAcct': 96,
#    'moSinOldRevTlOp': 173,
#    'moSinRcntRevTlOp': 11,
#    'moSinRcntTl': 11,
#    'mortAcc': 0,
#    'mtgPayment': 0.0,
#    'mthsSinceLastDelinq': None,
#    'mthsSinceLastMajorDerog': None,
#    'mthsSinceLastRecord': None,
#    'mthsSinceRcntIl': 20,
#    'mthsSinceRecentBc': 11,
#    'mthsSinceRecentBcDlq': None,
#    'mthsSinceRecentInq': 11,
#    'mthsSinceRecentRevolDelinq': None,
#    'numAcctsEver120Ppd': 0,
#    'numActvBcTl': 2,
#    'numActvRevTl': 2,
#    'numBcSats': 5,
#    'numBcTl': 6,
#    'numIlTl': 7,
#    'numOpRevTl': 7,
#    'numRevAccts': 12,
#    'numRevTlBalGt0': 2,
#    'numSats': 8,
#    'numTl120dpd2m': 0,
#    'numTl30dpd': 0,
#    'numTl90gDpd24m': 0,
#    'numTlOpPast12m': 1,
#    'openAcc': 8,
#    'openAcc6m': 0,
#    'openActIl': 1,
#    'openIl12m': 0,
#    'openIl24m': 1,
#    'openRv12m': 1,
#    'openRv24m': 2,
#    'pctTlNvrDlq': 100,
#    'percentBcGt75': 40.0,
#    'pubRec': 0,
#    'pubRecBankruptcies': 0,
#    'purpose': 'credit_card',
#    'reviewStatus': 'APPROVED',
#    'reviewStatusD': '2018-05-12T13:41:27.000-07:00',
#    'revolBal': 14076.0,
#    'revolBalJoint': None,
#    'revolUtil': 51.0,
#    'secAppChargeoffWithin12Mths': None,
#    'secAppCollections12MthsExMed': None,
#    'secAppEarliestCrLine': None,
#    'secAppFicoRangeHigh': None,
#    'secAppFicoRangeLow': None,
#    'secAppInqLast6Mths': None,
#    'secAppMortAcc': None,
#    'secAppMthsSinceLastMajorDerog': None,
#    'secAppNumRevAccts': None,
#    'secAppOpenAcc': None,
#    'secAppOpenActIl': None,
#    'secAppRevolUtil': None,
#    'serviceFeeRate': 0.83,
#    'subGrade': 'A1',
#    'taxLiens': 0,
#    'term': 36,
#    'totCollAmt': 0,
#    'totCurBal': 33627,
#    'totHiCredLim': 52600,
#    'totalAcc': 20,
#    'totalBalExMort': 33627,
#    'totalBalIl': 19551.0,
#    'totalBcLimit': 27600,
#    'totalCuTl': 0,
#    'totalIlHighCreditLimit': 25000,
#    'totalRevHiLim': 27600},
#   {'accNowDelinq': 0,
#    'accOpenPast24Mths': 3,
#    'acceptD': '2018-05-12T12:04:37.000-07:00',
#    'addrState': 'OH',
#    'addrZip': '453xx',
#    'allUtil': 51.2,
#    'annualInc': 100000.0,
#    'annualIncJoint': None,
#    'applicationType': 'INDIVIDUAL',
#    'avgCurBal': 15506,
#    'bcOpenToBuy': 21252,
#    'bcUtil': 28.9,
#    'chargeoffWithin12Mths': 0,
#    'collections12MthsExMed': 0,
#    'creditPullD': '2018-05-11T18:18:06.000-07:00',
#    'delinq2Yrs': 0,
#    'delinqAmnt': 0.0,
#    'desc': None,
#    'disbursementMethod': 'CASH',
#    'dti': 20.48,
#    'dtiJoint': None,
#    'earliestCrLine': '1992-02-11T16:00:00.000-08:00',
#    'empLength': 96,
#    'empTitle': 'Sr. Staff Engineer',
#    'expD': '2018-06-11T14:00:00.000-07:00',
#    'expDefaultRate': 1.88,
#    'ficoRangeHigh': 739,
#    'ficoRangeLow': 735,
#    'fundedAmount': 3025.0,
#    'grade': 'A',
#    'homeOwnership': 'MORTGAGE',
#    'housingPayment': 1300.0,
#    'iLUtil': 50.5,
#    'id': 133339155,
#    'ilsExpD': '2018-05-12T14:00:00.000-07:00',
#    'initialListStatus': 'F',
#    'inqFi': 1,
#    'inqLast12m': 0,
#    'inqLast6Mths': 0,
#    'installment': 292.88,
#    'intRate': 6.19,
#    'investorCount': None,
#    'isIncV': 'NOT_VERIFIED',
#    'isIncVJoint': None,
#    'listD': '2018-05-12T14:00:00.000-07:00',
#    'loanAmount': 9600.0,
#    'maxBalBc': 8410.0,
#    'memberId': 150302027,
#    'moSinOldIlAcct': 127,
#    'moSinOldRevTlOp': 246,
#    'moSinRcntRevTlOp': 3,
#    'moSinRcntTl': 3,
#    'mortAcc': 4,
#    'mtgPayment': 1371.67,
#    'mthsSinceLastDelinq': 53,
#    'mthsSinceLastMajorDerog': 53,
#    'mthsSinceLastRecord': None,
#    'mthsSinceRcntIl': 16,
#    'mthsSinceRecentBc': 3,
#    'mthsSinceRecentBcDlq': 53,
#    'mthsSinceRecentInq': 16,
#    'mthsSinceRecentRevolDelinq': 53,
#    'numAcctsEver120Ppd': 3,
#    'numActvBcTl': 2,
#    'numActvRevTl': 4,
#    'numBcSats': 6,
#    'numBcTl': 16,
#    'numIlTl': 7,
#    'numOpRevTl': 10,
#    'numRevAccts': 24,
#    'numRevTlBalGt0': 4,
#    'numSats': 13,
#    'numTl120dpd2m': 0,
#    'numTl30dpd': 0,
#    'numTl90gDpd24m': 0,
#    'numTlOpPast12m': 1,
#    'openAcc': 13,
#    'openAcc6m': 1,
#    'openActIl': 2,
#    'openIl12m': 0,
#    'openIl24m': 1,
#    'openRv12m': 1,
#    'openRv24m': 2,
#    'pctTlNvrDlq': 91,
#    'percentBcGt75': 16.7,
#    'pubRec': 0,
#    'pubRecBankruptcies': 0,
#    'purpose': 'major_purchase',
#    'reviewStatus': 'APPROVED',
#    'reviewStatusD': '2018-05-12T12:07:09.000-07:00',
#    'revolBal': 29981.0,
#    'revolBalJoint': None,
#    'revolUtil': 51.9,
#    'secAppChargeoffWithin12Mths': None,
#    'secAppCollections12MthsExMed': None,
#    'secAppEarliestCrLine': None,
#    'secAppFicoRangeHigh': None,
#    'secAppFicoRangeLow': None,
#    'secAppInqLast6Mths': None,
#    'secAppMortAcc': None,
#    'secAppMthsSinceLastMajorDerog': None,
#    'secAppNumRevAccts': None,
#    'secAppOpenAcc': None,
#    'secAppOpenActIl': None,
#    'secAppRevolUtil': None,
#    'serviceFeeRate': 0.83,
#    'subGrade': 'A2',
#    'taxLiens': 0,
#    'term': 36,
#    'totCollAmt': 0,
#    'totCurBal': 201576,
#    'totHiCredLim': 284140,
#    'totalAcc': 35,
#    'totalBalExMort': 54101,
#    'totalBalIl': 24120.0,
#    'totalBcLimit': 29900,
#    'totalCuTl': 0,
#    'totalIlHighCreditLimit': 47800,
#    'totalRevHiLim': 57800},
#   {'accNowDelinq': 0,
#    'accOpenPast24Mths': 7,
#    'acceptD': '2018-05-12T10:25:00.000-07:00',
#    'addrState': 'WI',
#    'addrZip': '549xx',
#    'allUtil': 26.4,
#    'annualInc': 30000.0,
#    'annualIncJoint': None,
#    'applicationType': 'INDIVIDUAL',
#    'avgCurBal': 5588,
#    'bcOpenToBuy': 1681,
#    'bcUtil': 16.0,
#    'chargeoffWithin12Mths': 0,
#    'collections12MthsExMed': 0,
#    'creditPullD': '2018-05-12T10:19:30.000-07:00',
#    'delinq2Yrs': 0,
#    'delinqAmnt': 0.0,
#    'desc': None,
#    'disbursementMethod': 'CASH',
#    'dti': 10.0,
#    'dtiJoint': None,
#    'earliestCrLine': '1990-06-11T17:00:00.000-07:00',
#    'empLength': 0,
#    'empTitle': 'PSR',
#    'expD': '2018-06-11T14:00:00.000-07:00',
#    'expDefaultRate': 3.95,
#    'ficoRangeHigh': 684,
#    'ficoRangeLow': 680,
#    'fundedAmount': 1750.0,
#    'grade': 'B',
#    'homeOwnership': 'MORTGAGE',
#    'housingPayment': 585.0,
#    'iLUtil': None,
#    'id': 133345651,
#    'ilsExpD': '2018-05-12T14:00:00.000-07:00',
#    'initialListStatus': 'F',
#    'inqFi': 0,
#    'inqLast12m': 4,
#    'inqLast6Mths': 2,
#    'installment': 332.77,
#    'intRate': 12.13,
#    'investorCount': None,
#    'isIncV': 'NOT_VERIFIED',
#    'isIncVJoint': None,
#    'listD': '2018-05-12T14:00:00.000-07:00',
#    'loanAmount': 10000.0,
#    'maxBalBc': 319.0,
#    'memberId': 150308601,
#    'moSinOldIlAcct': 199,
#    'moSinOldRevTlOp': 335,
#    'moSinRcntRevTlOp': 4,
#    'moSinRcntTl': 4,
#    'mortAcc': 3,
#    'mtgPayment': 584.0,
#    'mthsSinceLastDelinq': None,
#    'mthsSinceLastMajorDerog': None,
#    'mthsSinceLastRecord': 78,
#    'mthsSinceRcntIl': 43,
#    'mthsSinceRecentBc': 4,
#    'mthsSinceRecentBcDlq': None,
#    'mthsSinceRecentInq': 2,
#    'mthsSinceRecentRevolDelinq': None,
#    'numAcctsEver120Ppd': 0,
#    'numActvBcTl': 1,
#    'numActvRevTl': 6,
#    'numBcSats': 2,
#    'numBcTl': 3,
#    'numIlTl': 3,
#    'numOpRevTl': 12,
#    'numRevAccts': 20,
#    'numRevTlBalGt0': 6,
#    'numSats': 13,
#    'numTl120dpd2m': 0,
#    'numTl30dpd': 0,
#    'numTl90gDpd24m': 0,
#    'numTlOpPast12m': 6,
#    'openAcc': 13,
#    'openAcc6m': 1,
#    'openActIl': 0,
#    'openIl12m': 0,
#    'openIl24m': 0,
#    'openRv12m': 5,
#    'openRv24m': 6,
#    'pctTlNvrDlq': 100,
#    'percentBcGt75': 0.0,
#    'pubRec': 1,
#    'pubRecBankruptcies': 1,
#    'purpose': 'debt_consolidation',
#    'reviewStatus': 'APPROVED',
#    'reviewStatusD': '2018-05-12T10:30:23.000-07:00',
#    'revolBal': 5329.0,
#    'revolBalJoint': None,
#    'revolUtil': 26.4,
#    'secAppChargeoffWithin12Mths': None,
#    'secAppCollections12MthsExMed': None,
#    'secAppEarliestCrLine': None,
#    'secAppFicoRangeHigh': None,
#    'secAppFicoRangeLow': None,
#    'secAppInqLast6Mths': None,
#    'secAppMortAcc': None,
#    'secAppMthsSinceLastMajorDerog': None,
#    'secAppNumRevAccts': None,
#    'secAppOpenAcc': None,
#    'secAppOpenActIl': None,
#    'secAppRevolUtil': None,
#    'serviceFeeRate': 0.97,
#    'subGrade': 'B5',
#    'taxLiens': 0,
#    'term': 36,
#    'totCollAmt': 0,
#    'totCurBal': 72649,
#    'totHiCredLim': 88600,
#    'totalAcc': 26,
#    'totalBalExMort': 5329,
#    'totalBalIl': 0.0,
#    'totalBcLimit': 2000,
#    'totalCuTl': 1,
#    'totalIlHighCreditLimit': 0,
#    'totalRevHiLim': 20200},
#   {'accNowDelinq': 0,
#    'accOpenPast24Mths': 2,
#    'acceptD': '2018-05-12T11:16:52.000-07:00',
#    'addrState': 'WA',
#    'addrZip': '980xx',
#    'allUtil': 72.4,
#    'annualInc': 100000.0,
#    'annualIncJoint': None,
#    'applicationType': 'INDIVIDUAL',
#    'avgCurBal': 4685,
#    'bcOpenToBuy': 4943,
#    'bcUtil': 85.4,
#    'chargeoffWithin12Mths': 0,
#    'collections12MthsExMed': 0,
#    'creditPullD': '2018-05-12T10:47:21.000-07:00',
#    'delinq2Yrs': 0,
#    'delinqAmnt': 0.0,
#    'desc': None,
#    'disbursementMethod': 'CASH',
#    'dti': 18.72,
#    'dtiJoint': None,
#    'earliestCrLine': '2008-07-11T17:00:00.000-07:00',
#    'empLength': 60,
#    'empTitle': 'Web Developer',
#    'expD': '2018-06-11T14:00:00.000-07:00',
#    'expDefaultRate': 3.95,
#    'ficoRangeHigh': 679,
#    'ficoRangeLow': 675,
#    'fundedAmount': 22075.0,
#    'grade': 'B',
#    'homeOwnership': 'RENT',
#    'housingPayment': 1500.0,
#    'iLUtil': 62.4,
#    'id': 133343754,
#    'ilsExpD': '2018-05-12T14:00:00.000-07:00',
#    'initialListStatus': 'F',
#    'inqFi': 0,
#    'inqLast12m': 0,
#    'inqLast6Mths': 0,
#    'installment': 999.26,
#    'intRate': 11.05,
#    'investorCount': None,
#    'isIncV': 'NOT_VERIFIED',
#    'isIncVJoint': None,
#    'listD': '2018-05-12T14:00:00.000-07:00',
#    'loanAmount': 30500.0,
#    'maxBalBc': 16718.0,
#    'memberId': 150306737,
#    'moSinOldIlAcct': 104,
#    'moSinOldRevTlOp': 118,
#    'moSinRcntRevTlOp': 24,
#    'moSinRcntTl': 20,
#    'mortAcc': 0,
#    'mtgPayment': 0.0,
#    'mthsSinceLastDelinq': 26,
#    'mthsSinceLastMajorDerog': None,
#    'mthsSinceLastRecord': None,
#    'mthsSinceRcntIl': 20,
#    'mthsSinceRecentBc': 24,
#    'mthsSinceRecentBcDlq': None,
#    'mthsSinceRecentInq': 20,
#    'mthsSinceRecentRevolDelinq': 26,
#    'numAcctsEver120Ppd': 0,
#    'numActvBcTl': 4,
#    'numActvRevTl': 5,
#    'numBcSats': 5,
#    'numBcTl': 7,
#    'numIlTl': 11,
#    'numOpRevTl': 7,
#    'numRevAccts': 13,
#    'numRevTlBalGt0': 5,
#    'numSats': 12,
#    'numTl120dpd2m': 0,
#    'numTl30dpd': 0,
#    'numTl90gDpd24m': 0,
#    'numTlOpPast12m': 0,
#    'openAcc': 12,
#    'openAcc6m': 0,
#    'openActIl': 5,
#    'openIl12m': 0,
#    'openIl24m': 1,
#    'openRv12m': 0,
#    'openRv24m': 1,
#    'pctTlNvrDlq': 95,
#    'percentBcGt75': 80.0,
#    'pubRec': 0,
#    'pubRecBankruptcies': 0,
#    'purpose': 'credit_card',
#    'reviewStatus': 'APPROVED',
#    'reviewStatusD': '2018-05-12T11:22:27.000-07:00',
#    'revolBal': 31562.0,
#    'revolBalJoint': None,
#    'revolUtil': 82.8,
#    'secAppChargeoffWithin12Mths': None,
#    'secAppCollections12MthsExMed': None,
#    'secAppEarliestCrLine': None,
#    'secAppFicoRangeHigh': None,
#    'secAppFicoRangeLow': None,
#    'secAppInqLast6Mths': None,
#    'secAppMortAcc': None,
#    'secAppMthsSinceLastMajorDerog': None,
#    'secAppNumRevAccts': None,
#    'secAppOpenAcc': None,
#    'secAppOpenActIl': None,
#    'secAppRevolUtil': None,
#    'serviceFeeRate': 0.97,
#    'subGrade': 'B4',
#    'taxLiens': 0,
#    'term': 36,
#    'totCollAmt': 0,
#    'totCurBal': 56214,
#    'totHiCredLim': 77600,
#    'totalAcc': 24,
#    'totalBalExMort': 56214,
#    'totalBalIl': 24652.0,
#    'totalBcLimit': 33800,
#    'totalCuTl': 3,
#    'totalIlHighCreditLimit': 39500,
#    'totalRevHiLim': 38100},
#   {'accNowDelinq': 0,
#    'accOpenPast24Mths': 6,
#    'acceptD': '2018-05-10T17:59:15.000-07:00',
#    'addrState': 'IL',
#    'addrZip': '624xx',
#    'allUtil': 42.8,
#    'annualInc': 36420.0,
#    'annualIncJoint': None,
#    'applicationType': 'INDIVIDUAL',
#    'avgCurBal': 5530,
#    'bcOpenToBuy': 7639,
#    'bcUtil': 61.0,
#    'chargeoffWithin12Mths': 0,
#    'collections12MthsExMed': 0,
#    'creditPullD': '2018-05-10T17:43:05.000-07:00',
#    'delinq2Yrs': 1,
#    'delinqAmnt': 0.0,
#    'desc': None,
#    'disbursementMethod': 'DIRECT_PAY',
#    'dti': 18.78,
#    'dtiJoint': None,
#    'earliestCrLine': '1999-11-10T16:00:00.000-08:00',
#    'empLength': 120,
#    'empTitle': 'Shipping and receiving ',
#    'expD': '2018-06-11T14:00:00.000-07:00',
#    'expDefaultRate': 1.88,
#    'ficoRangeHigh': 729,
#    'ficoRangeLow': 725,
#    'fundedAmount': 3325.0,
#    'grade': 'A',
#    'homeOwnership': 'MORTGAGE',
#    'housingPayment': 620.0,
#    'iLUtil': 43.2,
#    'id': 133276491,
#    'ilsExpD': '2018-05-12T14:00:00.000-07:00',
#    'initialListStatus': 'F',
#    'inqFi': 0,
#    'inqLast12m': 2,
#    'inqLast6Mths': 0,
#    'installment': 366.1,
#    'intRate': 6.19,
#    'investorCount': None,
#    'isIncV': 'NOT_VERIFIED',
#    'isIncVJoint': None,
#    'listD': '2018-05-12T14:00:00.000-07:00',
#    'loanAmount': 12000.0,
#    'maxBalBc': 6803.0,
#    'memberId': 150215645,
#    'moSinOldIlAcct': 119,
#    'moSinOldRevTlOp': 222,
#    'moSinRcntRevTlOp': 10,
#    'moSinRcntTl': 10,
#    'mortAcc': 3,
#    'mtgPayment': 672.86,
#    'mthsSinceLastDelinq': 14,
#    'mthsSinceLastMajorDerog': None,
#    'mthsSinceLastRecord': None,
#    'mthsSinceRcntIl': 10,
#    'mthsSinceRecentBc': 10,
#    'mthsSinceRecentBcDlq': None,
#    'mthsSinceRecentInq': 10,
#    'mthsSinceRecentRevolDelinq': 14,
#    'numAcctsEver120Ppd': 0,
#    'numActvBcTl': 2,
#    'numActvRevTl': 2,
#    'numBcSats': 3,
#    'numBcTl': 9,
#    'numIlTl': 21,
#    'numOpRevTl': 6,
#    'numRevAccts': 14,
#    'numRevTlBalGt0': 2,
#    'numSats': 11,
#    'numTl120dpd2m': 0,
#    'numTl30dpd': 0,
#    'numTl90gDpd24m': 0,
#    'numTlOpPast12m': 2,
#    'openAcc': 11,
#    'openAcc6m': 0,
#    'openActIl': 4,
#    'openIl12m': 1,
#    'openIl24m': 2,
#    'openRv12m': 1,
#    'openRv24m': 4,
#    'pctTlNvrDlq': 97,
#    'percentBcGt75': 0.0,
#    'pubRec': 0,
#    'pubRecBankruptcies': 0,
#    'purpose': 'debt_consolidation',
#    'reviewStatus': 'APPROVED',
#    'reviewStatusD': '2018-05-12T09:53:31.000-07:00',
#    'revolBal': 11961.0,
#    'revolBalJoint': None,
#    'revolUtil': 42.6,
#    'secAppChargeoffWithin12Mths': None,
#    'secAppCollections12MthsExMed': None,
#    'secAppEarliestCrLine': None,
#    'secAppFicoRangeHigh': None,
#    'secAppFicoRangeLow': None,
#    'secAppInqLast6Mths': None,
#    'secAppMortAcc': None,
#    'secAppMthsSinceLastMajorDerog': None,
#    'secAppNumRevAccts': None,
#    'secAppOpenAcc': None,
#    'secAppOpenActIl': None,
#    'secAppRevolUtil': None,
#    'serviceFeeRate': 0.83,
#    'subGrade': 'A2',
#    'taxLiens': 0,
#    'term': 36,
#    'totCollAmt': 0,
#    'totCurBal': 60827,
#    'totHiCredLim': 107262,
#    'totalAcc': 38,
#    'totalBalExMort': 18948,
#    'totalBalIl': 6987.0,
#    'totalBcLimit': 19600,
#    'totalCuTl': 3,
#    'totalIlHighCreditLimit': 16162,
#    'totalRevHiLim': 28100},
#   {'accNowDelinq': 0,
#    'accOpenPast24Mths': 1,
#    'acceptD': '2018-05-10T17:19:54.000-07:00',
#    'addrState': 'NJ',
#    'addrZip': '079xx',
#    'allUtil': 5.0,
#    'annualInc': 210000.0,
#    'annualIncJoint': 227340.0,
#    'applicationType': 'JOINT',
#    'avgCurBal': 11794,
#    'bcOpenToBuy': 57950,
#    'bcUtil': 6.5,
#    'chargeoffWithin12Mths': 0,
#    'collections12MthsExMed': 0,
#    'creditPullD': '2018-05-10T17:12:42.000-07:00',
#    'delinq2Yrs': 0,
#    'delinqAmnt': 0.0,
#    'desc': None,
#    'disbursementMethod': 'DIRECT_PAY',
#    'dti': 6.35,
#    'dtiJoint': 10.0,
#    'earliestCrLine': '2000-03-10T16:00:00.000-08:00',
#    'empLength': 120,
#    'empTitle': 'Manager',
#    'expD': '2018-06-11T14:00:00.000-07:00',
#    'expDefaultRate': 2.27,
#    'ficoRangeHigh': 839,
#    'ficoRangeLow': 835,
#    'fundedAmount': 15600.0,
#    'grade': 'A',
#    'homeOwnership': 'OWN',
#    'housingPayment': None,
#    'iLUtil': None,
#    'id': 133276386,
#    'ilsExpD': '2018-05-12T14:00:00.000-07:00',
#    'initialListStatus': 'F',
#    'inqFi': 0,
#    'inqLast12m': 0,
#    'inqLast6Mths': 0,
#    'installment': 541.89,
#    'intRate': 5.31,
#    'investorCount': None,
#    'isIncV': 'NOT_VERIFIED',
#    'isIncVJoint': 'NOT_VERIFIED',
#    'listD': '2018-05-12T14:00:00.000-07:00',
#    'loanAmount': 28500.0,
#    'maxBalBc': 2121.0,
#    'memberId': 150215532,
#    'moSinOldIlAcct': 103,
#    'moSinOldRevTlOp': 218,
#    'moSinRcntRevTlOp': 20,
#    'moSinRcntTl': 20,
#    'mortAcc': 2,
#    'mtgPayment': 0.0,
#    'mthsSinceLastDelinq': None,
#    'mthsSinceLastMajorDerog': None,
#    'mthsSinceLastRecord': None,
#    'mthsSinceRcntIl': 91,
#    'mthsSinceRecentBc': 20,
#    'mthsSinceRecentBcDlq': None,
#    'mthsSinceRecentInq': 20,
#    'mthsSinceRecentRevolDelinq': None,
#    'numAcctsEver120Ppd': 0,
#    'numActvBcTl': 3,
#    'numActvRevTl': 4,
#    'numBcSats': 7,
#    'numBcTl': 13,
#    'numIlTl': 2,
#    'numOpRevTl': 11,
#    'numRevAccts': 22,
#    'numRevTlBalGt0': 4,
#    'numSats': 11,
#    'numTl120dpd2m': 0,
#    'numTl30dpd': 0,
#    'numTl90gDpd24m': 0,
#    'numTlOpPast12m': 0,
#    'openAcc': 11,
#    'openAcc6m': 0,
#    'openActIl': 0,
#    'openIl12m': 0,
#    'openIl24m': 0,
#    'openRv12m': 0,
#    'openRv24m': 1,
#    'pctTlNvrDlq': 100,
#    'percentBcGt75': 0.0,
#    'pubRec': 0,
#    'pubRecBankruptcies': 0,
#    'purpose': 'credit_card',
#    'reviewStatus': 'APPROVED',
#    'reviewStatusD': '2018-05-12T11:41:00.000-07:00',
#    'revolBal': 129738.0,
#    'revolBalJoint': None,
#    'revolUtil': 5.0,
#    'secAppChargeoffWithin12Mths': None,
#    'secAppCollections12MthsExMed': None,
#    'secAppEarliestCrLine': None,
#    'secAppFicoRangeHigh': None,
#    'secAppFicoRangeLow': None,
#    'secAppInqLast6Mths': None,
#    'secAppMortAcc': None,
#    'secAppMthsSinceLastMajorDerog': None,
#    'secAppNumRevAccts': None,
#    'secAppOpenAcc': None,
#    'secAppOpenActIl': None,
#    'secAppRevolUtil': None,
#    'serviceFeeRate': 0.59,
#    'subGrade': 'A1',
#    'taxLiens': 0,
#    'term': 60,
#    'totCollAmt': 0,
#    'totCurBal': 129738,
#    'totHiCredLim': 231000,
#    'totalAcc': 26,
#    'totalBalExMort': 129738,
#    'totalBalIl': 0.0,
#    'totalBcLimit': 62000,
#    'totalCuTl': 0,
#    'totalIlHighCreditLimit': 0,
#    'totalRevHiLim': 231000},
#   {'accNowDelinq': 0,
#    'accOpenPast24Mths': 1,
#    'acceptD': '2018-05-10T20:05:38.000-07:00',
#    'addrState': 'FL',
#    'addrZip': '336xx',
#    'allUtil': 61.9,
#    'annualInc': 94000.0,
#    'annualIncJoint': None,
#    'applicationType': 'INDIVIDUAL',
#    'avgCurBal': 18486,
#    'bcOpenToBuy': 22833,
#    'bcUtil': 59.4,
#    'chargeoffWithin12Mths': 0,
#    'collections12MthsExMed': 0,
#    'creditPullD': '2018-04-22T20:56:12.000-07:00',
#    'delinq2Yrs': 0,
#    'delinqAmnt': 0.0,
#    'desc': None,
#    'disbursementMethod': 'CASH',
#    'dti': 25.22,
#    'dtiJoint': None,
#    'earliestCrLine': '2003-10-22T17:00:00.000-07:00',
#    'empLength': 120,
#    'empTitle': 'Engineer',
#    'expD': '2018-06-11T14:00:00.000-07:00',
#    'expDefaultRate': 1.86,
#    'ficoRangeHigh': 699,
#    'ficoRangeLow': 695,
#    'fundedAmount': 15025.0,
#    'grade': 'A',
#    'homeOwnership': 'MORTGAGE',
#    'housingPayment': 1040.0,
#    'iLUtil': 69.1,
#    'id': 132103504,
#    'ilsExpD': '2018-05-12T14:00:00.000-07:00',
#    'initialListStatus': 'F',
#    'inqFi': 1,
#    'inqLast12m': 0,
#    'inqLast6Mths': 0,
#    'installment': 868.92,
#    'intRate': 7.34,
#    'investorCount': None,
#    'isIncV': 'NOT_VERIFIED',
#    'isIncVJoint': None,
#    'listD': '2018-05-12T14:00:00.000-07:00',
#    'loanAmount': 28000.0,
#    'maxBalBc': 7630.0,
#    'memberId': 148245369,
#    'moSinOldIlAcct': 136,
#    'moSinOldRevTlOp': 174,
#    'moSinRcntRevTlOp': 62,
#    'moSinRcntTl': 13,
#    'mortAcc': 1,
#    'mtgPayment': 1000.32,
#    'mthsSinceLastDelinq': None,
#    'mthsSinceLastMajorDerog': None,
#    'mthsSinceLastRecord': None,
#    'mthsSinceRcntIl': 13,
#    'mthsSinceRecentBc': 62,
#    'mthsSinceRecentBcDlq': None,
#    'mthsSinceRecentInq': 13,
#    'mthsSinceRecentRevolDelinq': None,
#    'numAcctsEver120Ppd': 0,
#    'numActvBcTl': 6,
#    'numActvRevTl': 8,
#    'numBcSats': 7,
#    'numBcTl': 11,
#    'numIlTl': 8,
#    'numOpRevTl': 9,
#    'numRevAccts': 13,
#    'numRevTlBalGt0': 8,
#    'numSats': 11,
#    'numTl120dpd2m': 0,
#    'numTl30dpd': 0,
#    'numTl90gDpd24m': 0,
#    'numTlOpPast12m': 0,
#    'openAcc': 11,
#    'openAcc6m': 0,
#    'openActIl': 1,
#    'openIl12m': 0,
#    'openIl24m': 1,
#    'openRv12m': 0,
#    'openRv24m': 0,
#    'pctTlNvrDlq': 100,
#    'percentBcGt75': 42.9,
#    'pubRec': 0,
#    'pubRecBankruptcies': 0,
#    'purpose': 'credit_card',
#    'reviewStatus': 'APPROVED',
#    'reviewStatusD': '2018-05-12T12:50:31.000-07:00',
#    'revolBal': 42461.0,
#    'revolBalJoint': None,
#    'revolUtil': 58.8,
#    'secAppChargeoffWithin12Mths': None,
#    'secAppCollections12MthsExMed': None,
#    'secAppEarliestCrLine': None,
#    'secAppFicoRangeHigh': None,
#    'secAppFicoRangeLow': None,
#    'secAppInqLast6Mths': None,
#    'secAppMortAcc': None,
#    'secAppMthsSinceLastMajorDerog': None,
#    'secAppNumRevAccts': None,
#    'secAppOpenAcc': None,
#    'secAppOpenActIl': None,
#    'secAppRevolUtil': None,
#    'serviceFeeRate': 0.83,
#    'subGrade': 'A4',
#    'taxLiens': 0,
#    'term': 36,
#    'totCollAmt': 0,
#    'totCurBal': 203350,
#    'totHiCredLim': 251750,
#    'totalAcc': 22,
#    'totalBalExMort': 64130,
#    'totalBalIl': 21669.0,
#    'totalBcLimit': 56300,
#    'totalCuTl': 2,
#    'totalIlHighCreditLimit': 31350,
#    'totalRevHiLim': 72200},
#   {'accNowDelinq': 0,
#    'accOpenPast24Mths': 12,
#    'acceptD': '2018-05-10T20:50:44.000-07:00',
#    'addrState': 'AR',
#    'addrZip': '727xx',
#    'allUtil': 56.0,
#    'annualInc': 72000.0,
#    'annualIncJoint': None,
#    'applicationType': 'INDIVIDUAL',
#    'avgCurBal': 6690,
#    'bcOpenToBuy': 5297,
#    'bcUtil': 73.5,
#    'chargeoffWithin12Mths': 0,
#    'collections12MthsExMed': 0,
#    'creditPullD': '2018-05-10T20:45:28.000-07:00',
#    'delinq2Yrs': 0,
#    'delinqAmnt': 0.0,
#    'desc': None,
#    'disbursementMethod': 'CASH',
#    'dti': 17.19,
#    'dtiJoint': None,
#    'earliestCrLine': '1996-03-10T16:00:00.000-08:00',
#    'empLength': 96,
#    'empTitle': 'Executive assistant',
#    'expD': '2018-06-11T14:00:00.000-07:00',
#    'expDefaultRate': 16.11,
#    'ficoRangeHigh': 669,
#    'ficoRangeLow': 665,
#    'fundedAmount': 5150.0,
#    'grade': 'E',
#    'homeOwnership': 'OWN',
#    'housingPayment': None,
#    'iLUtil': 75.5,
#    'id': 133284123,
#    'ilsExpD': '2018-05-12T14:00:00.000-07:00',
#    'initialListStatus': 'F',
#    'inqFi': 1,
#    'inqLast12m': 3,
#    'inqLast6Mths': 1,
#    'installment': 596.57,
#    'intRate': 25.81,
#    'investorCount': None,
#    'isIncV': 'NOT_VERIFIED',
#    'isIncVJoint': None,
#    'listD': '2018-05-12T14:00:00.000-07:00',
#    'loanAmount': 20000.0,
#    'maxBalBc': 4996.0,
#    'memberId': 150224298,
#    'moSinOldIlAcct': 22,
#    'moSinOldRevTlOp': 266,
#    'moSinRcntRevTlOp': 6,
#    'moSinRcntTl': 6,
#    'mortAcc': 2,
#    'mtgPayment': 769.2,
#    'mthsSinceLastDelinq': 32,
#    'mthsSinceLastMajorDerog': 41,
#    'mthsSinceLastRecord': None,
#    'mthsSinceRcntIl': 22,
#    'mthsSinceRecentBc': 9,
#    'mthsSinceRecentBcDlq': None,
#    'mthsSinceRecentInq': 6,
#    'mthsSinceRecentRevolDelinq': None,
#    'numAcctsEver120Ppd': 1,
#    'numActvBcTl': 5,
#    'numActvRevTl': 7,
#    'numBcSats': 7,
#    'numBcTl': 8,
#    'numIlTl': 1,
#    'numOpRevTl': 16,
#    'numRevAccts': 20,
#    'numRevTlBalGt0': 7,
#    'numSats': 19,
#    'numTl120dpd2m': 0,
#    'numTl30dpd': 0,
#    'numTl90gDpd24m': 0,
#    'numTlOpPast12m': 5,
#    'openAcc': 19,
#    'openAcc6m': 1,
#    'openActIl': 1,
#    'openIl12m': 0,
#    'openIl24m': 1,
#    'openRv12m': 5,
#    'openRv24m': 10,
#    'pctTlNvrDlq': 100,
#    'percentBcGt75': 71.4,
#    'pubRec': 0,
#    'pubRecBankruptcies': 0,
#    'purpose': 'medical',
#    'reviewStatus': 'APPROVED',
#    'reviewStatusD': '2018-05-12T13:11:39.000-07:00',
#    'revolBal': 16821.0,
#    'revolBalJoint': None,
#    'revolUtil': 46.3,
#    'secAppChargeoffWithin12Mths': None,
#    'secAppCollections12MthsExMed': None,
#    'secAppEarliestCrLine': None,
#    'secAppFicoRangeHigh': None,
#    'secAppFicoRangeLow': None,
#    'secAppInqLast6Mths': None,
#    'secAppMortAcc': None,
#    'secAppMthsSinceLastMajorDerog': None,
#    'secAppNumRevAccts': None,
#    'secAppOpenAcc': None,
#    'secAppOpenActIl': None,
#    'secAppRevolUtil': None,
#    'serviceFeeRate': 1.26,
#    'subGrade': 'E4',
#    'taxLiens': 0,
#    'term': 60,
#    'totCollAmt': 1318,
#    'totCurBal': 127119,
#    'totHiCredLim': 153486,
#    'totalAcc': 24,
#    'totalBalExMort': 29446,
#    'totalBalIl': 11311.0,
#    'totalBcLimit': 20000,
#    'totalCuTl': 0,
#    'totalIlHighCreditLimit': 14975,
#    'totalRevHiLim': 36300},
#   {'accNowDelinq': 0,
#    'accOpenPast24Mths': 6,
#    'acceptD': '2018-05-07T20:48:59.000-07:00',
#    'addrState': 'TX',
#    'addrZip': '798xx',
#    'allUtil': 39.2,
#    'annualInc': 110000.0,
#    'annualIncJoint': 275000.0,
#    'applicationType': 'JOINT',
#    'avgCurBal': 42205,
#    'bcOpenToBuy': 2982,
#    'bcUtil': 50.3,
#    'chargeoffWithin12Mths': 0,
#    'collections12MthsExMed': 0,
#    'creditPullD': '2018-05-07T20:43:47.000-07:00',
#    'delinq2Yrs': 1,
#    'delinqAmnt': 0.0,
#    'desc': None,
#    'disbursementMethod': 'CASH',
#    'dti': 13.96,
#    'dtiJoint': 9.74,
#    'earliestCrLine': '1998-12-07T16:00:00.000-08:00',
#    'empLength': 48,
#    'empTitle': 'CNO/RN',
#    'expD': '2018-06-11T14:00:00.000-07:00',
#    'expDefaultRate': 1.86,
#    'ficoRangeHigh': 704,
#    'ficoRangeLow': 700,
#    'fundedAmount': 7075.0,
#    'grade': 'A',
#    'homeOwnership': 'MORTGAGE',
#    'housingPayment': 820.0,
#    'iLUtil': None,
#    'id': 132993312,
#    'ilsExpD': '2018-05-12T14:00:00.000-07:00',
#    'initialListStatus': 'F',
#    'inqFi': 1,
#    'inqLast12m': 1,
#    'inqLast6Mths': 0,
#    'installment': 768.62,
#    'intRate': 6.71,
#    'investorCount': None,
#    'isIncV': 'VERIFIED',
#    'isIncVJoint': 'VERIFIED',
#    'listD': '2018-05-12T14:00:00.000-07:00',
#    'loanAmount': 25000.0,
#    'maxBalBc': 1450.0,
#    'memberId': 149799135,
#    'moSinOldIlAcct': 105,
#    'moSinOldRevTlOp': 233,
#    'moSinRcntRevTlOp': 8,
#    'moSinRcntTl': 8,
#    'mortAcc': 4,
#    'mtgPayment': 3125.83,
#    'mthsSinceLastDelinq': 10,
#    'mthsSinceLastMajorDerog': 10,
#    'mthsSinceLastRecord': None,
#    'mthsSinceRcntIl': 14,
#    'mthsSinceRecentBc': 8,
#    'mthsSinceRecentBcDlq': 42,
#    'mthsSinceRecentInq': 12,
#    'mthsSinceRecentRevolDelinq': 42,
#    'numAcctsEver120Ppd': 7,
#    'numActvBcTl': 3,
#    'numActvRevTl': 3,
#    'numBcSats': 3,
#    'numBcTl': 12,
#    'numIlTl': 3,
#    'numOpRevTl': 7,
#    'numRevAccts': 22,
#    'numRevTlBalGt0': 3,
#    'numSats': 11,
#    'numTl120dpd2m': 0,
#    'numTl30dpd': 0,
#    'numTl90gDpd24m': 1,
#    'numTlOpPast12m': 3,
#    'openAcc': 11,
#    'openAcc6m': 0,
#    'openActIl': 2,
#    'openIl12m': 0,
#    'openIl24m': 1,
#    'openRv12m': 3,
#    'openRv24m': 3,
#    'pctTlNvrDlq': 75,
#    'percentBcGt75': 0.0,
#    'pubRec': 0,
#    'pubRecBankruptcies': 0,
#    'purpose': 'home_improvement',
#    'reviewStatus': 'APPROVED',
#    'reviewStatusD': '2018-05-12T11:51:24.000-07:00',
#    'revolBal': 3018.0,
#    'revolBalJoint': 4640,
#    'revolUtil': 39.2,
#    'secAppChargeoffWithin12Mths': 0,
#    'secAppCollections12MthsExMed': 0,
#    'secAppEarliestCrLine': '1998-12-07T16:00:00.000-08:00',
#    'secAppFicoRangeHigh': 669,
#    'secAppFicoRangeLow': 665,
#    'secAppInqLast6Mths': 0,
#    'secAppMortAcc': 4,
#    'secAppMthsSinceLastMajorDerog': 10,
#    'secAppNumRevAccts': 9,
#    'secAppOpenAcc': 8,
#    'secAppOpenActIl': 4,
#    'secAppRevolUtil': 16.4,
#    'serviceFeeRate': 0.83,
#    'subGrade': 'A3',
#    'taxLiens': 0,
#    'term': 36,
#    'totCollAmt': 0,
#    'totCurBal': 379844,
#    'totHiCredLim': 413098,
#    'totalAcc': 29,
#    'totalBalExMort': 68254,
#    'totalBalIl': 65236.0,
#    'totalBcLimit': 6000,
#    'totalCuTl': 1,
#    'totalIlHighCreditLimit': 84070,
#    'totalRevHiLim': 7700},
#   {'accNowDelinq': 0,
#    'accOpenPast24Mths': 5,
#    'acceptD': '2018-05-12T12:59:26.000-07:00',
#    'addrState': 'GA',
#    'addrZip': '309xx',
#    'allUtil': 49.3,
#    'annualInc': 50400.0,
#    'annualIncJoint': None,
#    'applicationType': 'INDIVIDUAL',
#    'avgCurBal': 1277,
#    'bcOpenToBuy': 6278,
#    'bcUtil': 7.7,
#    'chargeoffWithin12Mths': 0,
#    'collections12MthsExMed': 0,
#    'creditPullD': '2018-05-12T11:27:54.000-07:00',
#    'delinq2Yrs': 0,
#    'delinqAmnt': 0.0,
#    'desc': None,
#    'disbursementMethod': 'CASH',
#    'dti': 12.93,
#    'dtiJoint': None,
#    'earliestCrLine': '2008-09-11T17:00:00.000-07:00',
#    'empLength': 36,
#    'empTitle': 'MT',
#    'expD': '2018-06-11T14:00:00.000-07:00',
#    'expDefaultRate': 11.46,
#    'ficoRangeHigh': 674,
#    'ficoRangeLow': 670,
#    'fundedAmount': 2675.0,
#    'grade': 'D',
#    'homeOwnership': 'MORTGAGE',
#    'housingPayment': 1000.0,
#    'iLUtil': 91.3,
#    'id': 133343845,
#    'ilsExpD': '2018-05-12T14:00:00.000-07:00',
#    'initialListStatus': 'F',
#    'inqFi': 4,
#    'inqLast12m': 4,
#    'inqLast6Mths': 1,
#    'installment': 1018.6,
#    'intRate': 18.45,
#    'investorCount': None,
#    'isIncV': 'NOT_VERIFIED',
#    'isIncVJoint': None,
#    'listD': '2018-05-12T14:00:00.000-07:00',
#    'loanAmount': 28000.0,
#    'maxBalBc': 507.0,
#    'memberId': 150317832,
#    'moSinOldIlAcct': 85,
#    'moSinOldRevTlOp': 116,
#    'moSinRcntRevTlOp': 4,
#    'moSinRcntTl': 4,
#    'mortAcc': 0,
#    'mtgPayment': 0.0,
#    'mthsSinceLastDelinq': 26,
#    'mthsSinceLastMajorDerog': None,
#    'mthsSinceLastRecord': None,
#    'mthsSinceRcntIl': 7,
#    'mthsSinceRecentBc': 27,
#    'mthsSinceRecentBcDlq': None,
#    'mthsSinceRecentInq': 1,
#    'mthsSinceRecentRevolDelinq': 26,
#    'numAcctsEver120Ppd': 0,
#    'numActvBcTl': 2,
#    'numActvRevTl': 7,
#    'numBcSats': 3,
#    'numBcTl': 4,
#    'numIlTl': 3,
#    'numOpRevTl': 10,
#    'numRevAccts': 14,
#    'numRevTlBalGt0': 7,
#    'numSats': 11,
#    'numTl120dpd2m': 0,
#    'numTl30dpd': 0,
#    'numTl90gDpd24m': 0,
#    'numTlOpPast12m': 3,
#    'openAcc': 11,
#    'openAcc6m': 2,
#    'openActIl': 1,
#    'openIl12m': 1,
#    'openIl24m': 1,
#    'openRv12m': 2,
#    'openRv24m': 4,
#    'pctTlNvrDlq': 94,
#    'percentBcGt75': 0.0,
#    'pubRec': 0,
#    'pubRecBankruptcies': 0,
#    'purpose': 'other',
#    'reviewStatus': 'APPROVED',
#    'reviewStatusD': '2018-05-12T13:17:24.000-07:00',
#    'revolBal': 6651.0,
#    'revolBalJoint': None,
#    'revolUtil': 32.6,
#    'secAppChargeoffWithin12Mths': None,
#    'secAppCollections12MthsExMed': None,
#    'secAppEarliestCrLine': None,
#    'secAppFicoRangeHigh': None,
#    'secAppFicoRangeLow': None,
#    'secAppInqLast6Mths': None,
#    'secAppMortAcc': None,
#    'secAppMthsSinceLastMajorDerog': None,
#    'secAppNumRevAccts': None,
#    'secAppOpenAcc': None,
#    'secAppOpenActIl': None,
#    'secAppRevolUtil': None,
#    'serviceFeeRate': 1.37,
#    'subGrade': 'D2',
#    'taxLiens': 0,
#    'term': 36,
#    'totCollAmt': 0,
#    'totCurBal': 14042,
#    'totHiCredLim': 28495,
#    'totalAcc': 17,
#    'totalBalExMort': 14042,
#    'totalBalIl': 7391.0,
#    'totalBcLimit': 6800,
#    'totalCuTl': 3,
#    'totalIlHighCreditLimit': 8095,
#    'totalRevHiLim': 20400}]}

# %%
# save loan data in json as myData
data = r.json()
myData =data['loans']

# %% [markdown]
# ## 1.1 save current loan data pulled from API into *current_list.txt *load current list into *df_current*
#
#
# Loan data from Lending Club is in Json format and it should be saved into local txt file.

# %%
# dump myData into current_list.txt 
with open('data/current_list.txt', 'w') as outfile:
    json.dump(myData, outfile)

# %%
# load current loan info into df_current from current_list.txt
df_current=pd.read_json('data/current_list.txt')

# %%
# check df_current
df_current.head()
# Out:
#    accNowDelinq  accOpenPast24Mths                        acceptD addrState  \
# 0             0                  1  2018-05-12T13:31:59.000-07:00        IL
# 1             0                  7  2018-05-12T12:52:47.000-07:00        CA
# 2             0                  2  2018-05-09T16:11:02.000-07:00        FL
# 3             0                  5  2018-05-12T13:22:41.000-07:00        CA
# 4             0                  7  2018-05-10T18:26:21.000-07:00        AZ
#
#   addrZip  allUtil  annualInc  annualIncJoint applicationType  avgCurBal  \
# 0   604xx     64.9      30000         97000.0           JOINT      21459
# 1   957xx     90.1      40000             NaN      INDIVIDUAL       4876
# 2   331xx     39.3      40000             NaN      INDIVIDUAL       1242
# 3   920xx     32.9      39000             NaN      INDIVIDUAL        493
# 4   852xx     51.7      40000             NaN      INDIVIDUAL      12899
#
#        ...        totCollAmt  totCurBal  totHiCredLim  totalAcc  \
# 0      ...                 0     107295        122353        11
# 1      ...              3174      43882         48729        15
# 2      ...                 0       7452         18943         6
# 3      ...                 0       1972          6000         6
# 4      ...                 0     270871        238550        37
#
#   totalBalExMort  totalBalIl  totalBcLimit  totalCuTl totalIlHighCreditLimit  \
# 0           6827        1695          1600          0                   3017
# 1          43882       38922          7900          1                  39829
# 2           7452         284          5800          0                  10243
# 3           1972           0          4500          1                      0
# 4         244128      224976         22200          2                 165150
#
#    totalRevHiLim
# 0           7500
# 1           8700
# 2           8700
# 3           6000
# 4          38400
#
# [5 rows x 119 columns]

# %%
# check df_current
df_current.tail()
# Out:
#     accNowDelinq  accOpenPast24Mths                        acceptD addrState  \
# 14             0                  1  2018-05-10T17:19:54.000-07:00        NJ
# 15             0                  1  2018-05-10T20:05:38.000-07:00        FL
# 16             0                 12  2018-05-10T20:50:44.000-07:00        AR
# 17             0                  6  2018-05-07T20:48:59.000-07:00        TX
# 18             0                  5  2018-05-12T12:59:26.000-07:00        GA
#
#    addrZip  allUtil  annualInc  annualIncJoint applicationType  avgCurBal  \
# 14   079xx      5.0     210000        227340.0           JOINT      11794
# 15   336xx     61.9      94000             NaN      INDIVIDUAL      18486
# 16   727xx     56.0      72000             NaN      INDIVIDUAL       6690
# 17   798xx     39.2     110000        275000.0           JOINT      42205
# 18   309xx     49.3      50400             NaN      INDIVIDUAL       1277
#
#         ...        totCollAmt  totCurBal  totHiCredLim  totalAcc  \
# 14      ...                 0     129738        231000        26
# 15      ...                 0     203350        251750        22
# 16      ...              1318     127119        153486        24
# 17      ...                 0     379844        413098        29
# 18      ...                 0      14042         28495        17
#
#    totalBalExMort  totalBalIl  totalBcLimit  totalCuTl totalIlHighCreditLimit  \
# 14         129738           0         62000          0                      0
# 15          64130       21669         56300          2                  31350
# 16          29446       11311         20000          0                  14975
# 17          68254       65236          6000          1                  84070
# 18          14042        7391          6800          3                   8095
#
#     totalRevHiLim
# 14         231000
# 15          72200
# 16          36300
# 17           7700
# 18          20400
#
# [5 rows x 119 columns]

# %%
# check current data shape
df_current.shape
# Out:
# (19, 119)

# %% [markdown]
# note that lending club provides 119 features for current loans

# %% [markdown]
# # 2. Load historical data in 2014
#
# In this project, we are only using loans with 36 months terms.
#
# For model training, we must focus on loans that have been completed, in which the final status of the loan, i.e. Paid or Defaulted, is known. Consequently, all the loans issued after 2015 needs to be eliminated because of their unmatured status.
#
# Additionally, because of the time sensitive nature of loan data, we plan to use the newest data available, which are the loans originated in 2014.

# %%
# historical loan data in loan_2014.csv
df_2014 = pd.read_csv('Data/loan_2014.csv', skiprows=0)
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (5,46) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# check historical loan data
df_2014.head()
# Out:
#    numtl120dpd2m  totalbalexmort  inqfi  accopenpast24mths  avgcurbal  \
# 0            0.0         15030.0    NaN                7.0     9536.0
# 1            0.0        149140.0    NaN                5.0    29828.0
# 2            0.0         38566.0    NaN                8.0     3214.0
# 3            0.0         64426.0    NaN                6.0     5857.0
# 4            0.0         18007.0    NaN                2.0    32727.0
#
#          id  mosinoldrevtlop  openacc  numrevtlbalgt0  inqlast6mths  \
# 0  36805548            290.0     17.0             9.0           2.0
# 1  38098114            244.0      6.0             4.0           0.0
# 2  37822187            265.0     12.0             7.0           0.0
# 3  37662224            148.0     11.0             4.0           1.0
# 4  37612354            170.0      8.0             5.0           0.0
#
#       ...       intrate addrstate zipcode  fundedamnt  verificationstatus  \
# 0     ...         6.99%        CA   937xx     10400.0        Not Verified
# 1     ...        12.39%        VA   235xx     15000.0     Source Verified
# 2     ...        13.66%        NJ   077xx      9600.0     Source Verified
# 3     ...        13.66%        AZ   850xx      7650.0     Source Verified
# 4     ...        17.14%        CA   953xx     12800.0            Verified
#
#    verificationstatusjoint  loanamnt  numacctsever120pd    issued   loanstatus
# 0                      NaN   10400.0                4.0  Dec-2014  Charged Off
# 1                      NaN   15000.0                0.0  Dec-2014   Fully Paid
# 2                      NaN    9600.0                0.0  Dec-2014   Fully Paid
# 3                      NaN    7650.0                0.0  Dec-2014  Charged Off
# 4                      NaN   12800.0                1.0  Dec-2014      Current
#
# [5 rows x 94 columns]

# %%
# check historical loan data
# note that there are two NAN rows at the end of the dataframe
df_2014.tail()
# Out:
#         numtl120dpd2m  totalbalexmort  inqfi  accopenpast24mths  avgcurbal  \
# 235626            0.0         50896.0    NaN                7.0    28172.0
# 235627            0.0         73598.0    NaN                8.0     4089.0
# 235628            0.0         57477.0    NaN                4.0    11495.0
# 235629            NaN             NaN    NaN                NaN        NaN
# 235630            NaN             NaN    NaN                NaN        NaN
#
#                                                       id  mosinoldrevtlop  \
# 235626                                           9604874            130.0
# 235627                                           9584776             93.0
# 235628                                           9199665            166.0
# 235629  Total amount funded in policy code 1: 3503840175              NaN
# 235630   Total amount funded in policy code 2: 873652739              NaN
#
#         openacc  numrevtlbalgt0  inqlast6mths     ...      intrate addrstate  \
# 235626     21.0             3.0           1.0     ...        7.90%        CA
# 235627     18.0             2.0           2.0     ...       16.99%        OH
# 235628      6.0             2.0           0.0     ...       19.20%        CA
# 235629      NaN             NaN           NaN     ...          NaN       NaN
# 235630      NaN             NaN           NaN     ...          NaN       NaN
#
#        zipcode  fundedamnt  verificationstatus  verificationstatusjoint  \
# 235626   913xx      2000.0            Verified                      NaN
# 235627   458xx     20700.0            Verified                      NaN
# 235628   950xx     10000.0            Verified                      NaN
# 235629     NaN         NaN                 NaN                      NaN
# 235630     NaN         NaN                 NaN                      NaN
#
#         loanamnt  numacctsever120pd    issued  loanstatus
# 235626    2000.0                0.0  Jan-2014  Fully Paid
# 235627   20700.0                0.0  Jan-2014     Current
# 235628   10000.0                0.0  Jan-2014  Fully Paid
# 235629       NaN                NaN       NaN         NaN
# 235630       NaN                NaN       NaN         NaN
#
# [5 rows x 94 columns]

# %%
# check the shape of the dataframe
df_2014.shape
# Out:
# (235631, 94)

# %%
# features existing in current data
print ('----------current-----------------')
for col in df_current.columns.values:
    print (col)
print ('----------current-----------------')
# Out:
# ----------current-----------------
# accNowDelinq
# accOpenPast24Mths
# acceptD
# addrState
# addrZip
# allUtil
# annualInc
# annualIncJoint
# applicationType
# avgCurBal
# bcOpenToBuy
# bcUtil
# chargeoffWithin12Mths
# collections12MthsExMed
# creditPullD
# delinq2Yrs
# delinqAmnt
# desc
# disbursementMethod
# dti
# dtiJoint
# earliestCrLine
# empLength
# empTitle
# expD
# expDefaultRate
# ficoRangeHigh
# ficoRangeLow
# fundedAmount
# grade
# homeOwnership
# housingPayment
# iLUtil
# id
# ilsExpD
# initialListStatus
# inqFi
# inqLast12m
# inqLast6Mths
# installment
# intRate
# investorCount
# isIncV
# isIncVJoint
# listD
# loanAmount
# maxBalBc
# memberId
# moSinOldIlAcct
# moSinOldRevTlOp
# moSinRcntRevTlOp
# moSinRcntTl
# mortAcc
# mtgPayment
# mthsSinceLastDelinq
# mthsSinceLastMajorDerog
# mthsSinceLastRecord
# mthsSinceRcntIl
# mthsSinceRecentBc
# mthsSinceRecentBcDlq
# mthsSinceRecentInq
# mthsSinceRecentRevolDelinq
# numAcctsEver120Ppd
# numActvBcTl
# numActvRevTl
# numBcSats
# numBcTl
# numIlTl
# numOpRevTl
# numRevAccts
# numRevTlBalGt0
# numSats
# numTl120dpd2m
# numTl30dpd
# numTl90gDpd24m
# numTlOpPast12m
# openAcc
# openAcc6m
# openActIl
# openIl12m
# openIl24m
# openRv12m
# openRv24m
# pctTlNvrDlq
# percentBcGt75
# pubRec
# pubRecBankruptcies
# purpose
# reviewStatus
# reviewStatusD
# revolBal
# revolBalJoint
# revolUtil
# secAppChargeoffWithin12Mths
# secAppCollections12MthsExMed
# secAppEarliestCrLine
# secAppFicoRangeHigh
# secAppFicoRangeLow
# secAppInqLast6Mths
# secAppMortAcc
# secAppMthsSinceLastMajorDerog
# secAppNumRevAccts
# secAppOpenAcc
# secAppOpenActIl
# secAppRevolUtil
# serviceFeeRate
# subGrade
# taxLiens
# term
# totCollAmt
# totCurBal
# totHiCredLim
# totalAcc
# totalBalExMort
# totalBalIl
# totalBcLimit
# totalCuTl
# totalIlHighCreditLimit
# totalRevHiLim
# ----------current-----------------

# %%
# features existing in current data
print ('----------2014-----------------')
for col in df_2014.columns.values:
    print (col)
print ('----------2014-----------------')
# Out:
# ----------2014-----------------
# numtl120dpd2m
# totalbalexmort
# inqfi
# accopenpast24mths
# avgcurbal
# id
# mosinoldrevtlop
# openacc
# numrevtlbalgt0
# inqlast6mths
# totalilhighcreditlimit
# revolutil
# grade
# mortacc
# mthssincercntil
# mthssincelastrecord
# tothicredlim
# memberid
# mthssincerecentbc
# numtl90gdpd24m
# maxbalbc
# numiltl
# totalrevhilim
# mthssincerecentbcdlq
# ficorangelow
# mthssincerecentrevoldelinq
# initialliststatus
# numbcsats
# numsats
# bcopentobuy
# openil24m
# applicationtype
# delinqamnt
# openrv24m
# percentbcgt75
# taxliens
# installment
# ficorangehigh
# mosinoldilacct
# subgrade
# numactvrevtl
# numtloppast12m
# openrv12m
# numactvbctl
# chargeoffwithin12mths
# numbctl
# desc
# allutil
# ilutil
# pubrec
# bcutil
# pcttlnvrdlq
# totalcutl
# mthssincelastmajorderog
# accnowdelinq
# totalbalil
# totcollamt
# mthssincerecentinq
# mosinrcntrevtlop
# openil12m
# totalbclimit
# dtijoint
# homeownership
# pubrecbankruptcies
# numoprevtl
# revolbal
# annualinc
# totalacc
# mthssincelastdelinq
# delinq2yrs
# collections12mthsexmed
# numtl30dpd
# purpose
# annualincjoint
# mosinrcnttl
# openacc6m
# term
# totcurbal
# numrevaccts
# emplength
# inqlast12m
# emptitle
# dti
# earliestcrline
# intrate
# addrstate
# zipcode
# fundedamnt
# verificationstatus
# verificationstatusjoint
# loanamnt
# numacctsever120pd
# issued
# loanstatus
# ----------2014-----------------

# %% [markdown]
# # 3. find commom features shared by current and historical data
#
# There are only 95 features in the historical data in 2014, while there are 119 features in current data obtained in April, 2018. This is probably due to the change in the information gathering by Lending Club.
#
# It is necessary to find out common features shared by both 2014 data and current data, since we are going to use 2014 historical data to predict loan default in current data. Features that are not shared by 2014 and current data are not useful for our model and need to be removed.

# %%
current_feature = list(df_current.columns.values)

# %% [markdown]
# ## processing of feature name for current data and historical data
#
# Additionally, it has been noticed that there are also some changes in feature names between 2014 and 2018, i.e. some features in 2014 loans may have different names in current loans. So it is necessary to unify the nomenclature of features for current loans and 2014 loans.
#
# One additional difference between 2014 loan features and current loan features comes from the format of the feature names. For example, some features in current loans are named following the Camel-Case guidance, while some features in 2014 are using underscore (“_”). Features names should be formatted using the same rule before usage.

# %%
# convert current feature into lower case
for i in range (len(current_feature)):
    current_feature[i] = str.lower(str(current_feature[i]))

# %%
current_feature
# Out:
# ['accnowdelinq',
#  'accopenpast24mths',
#  'acceptd',
#  'addrstate',
#  'addrzip',
#  'allutil',
#  'annualinc',
#  'annualincjoint',
#  'applicationtype',
#  'avgcurbal',
#  'bcopentobuy',
#  'bcutil',
#  'chargeoffwithin12mths',
#  'collections12mthsexmed',
#  'creditpulld',
#  'delinq2yrs',
#  'delinqamnt',
#  'desc',
#  'disbursementmethod',
#  'dti',
#  'dtijoint',
#  'earliestcrline',
#  'emplength',
#  'emptitle',
#  'expd',
#  'expdefaultrate',
#  'ficorangehigh',
#  'ficorangelow',
#  'fundedamount',
#  'grade',
#  'homeownership',
#  'housingpayment',
#  'ilutil',
#  'id',
#  'ilsexpd',
#  'initialliststatus',
#  'inqfi',
#  'inqlast12m',
#  'inqlast6mths',
#  'installment',
#  'intrate',
#  'investorcount',
#  'isincv',
#  'isincvjoint',
#  'listd',
#  'loanamount',
#  'maxbalbc',
#  'memberid',
#  'mosinoldilacct',
#  'mosinoldrevtlop',
#  'mosinrcntrevtlop',
#  'mosinrcnttl',
#  'mortacc',
#  'mtgpayment',
#  'mthssincelastdelinq',
#  'mthssincelastmajorderog',
#  'mthssincelastrecord',
#  'mthssincercntil',
#  'mthssincerecentbc',
#  'mthssincerecentbcdlq',
#  'mthssincerecentinq',
#  'mthssincerecentrevoldelinq',
#  'numacctsever120ppd',
#  'numactvbctl',
#  'numactvrevtl',
#  'numbcsats',
#  'numbctl',
#  'numiltl',
#  'numoprevtl',
#  'numrevaccts',
#  'numrevtlbalgt0',
#  'numsats',
#  'numtl120dpd2m',
#  'numtl30dpd',
#  'numtl90gdpd24m',
#  'numtloppast12m',
#  'openacc',
#  'openacc6m',
#  'openactil',
#  'openil12m',
#  'openil24m',
#  'openrv12m',
#  'openrv24m',
#  'pcttlnvrdlq',
#  'percentbcgt75',
#  'pubrec',
#  'pubrecbankruptcies',
#  'purpose',
#  'reviewstatus',
#  'reviewstatusd',
#  'revolbal',
#  'revolbaljoint',
#  'revolutil',
#  'secappchargeoffwithin12mths',
#  'secappcollections12mthsexmed',
#  'secappearliestcrline',
#  'secappficorangehigh',
#  'secappficorangelow',
#  'secappinqlast6mths',
#  'secappmortacc',
#  'secappmthssincelastmajorderog',
#  'secappnumrevaccts',
#  'secappopenacc',
#  'secappopenactil',
#  'secapprevolutil',
#  'servicefeerate',
#  'subgrade',
#  'taxliens',
#  'term',
#  'totcollamt',
#  'totcurbal',
#  'tothicredlim',
#  'totalacc',
#  'totalbalexmort',
#  'totalbalil',
#  'totalbclimit',
#  'totalcutl',
#  'totalilhighcreditlimit',
#  'totalrevhilim']

# %%
# save df_2014 feature into his_feature
his_feature = list(df_2014.columns.values)

# %%
his_feature
# Out:
# ['numtl120dpd2m',
#  'totalbalexmort',
#  'inqfi',
#  'accopenpast24mths',
#  'avgcurbal',
#  'id',
#  'mosinoldrevtlop',
#  'openacc',
#  'numrevtlbalgt0',
#  'inqlast6mths',
#  'totalilhighcreditlimit',
#  'revolutil',
#  'grade',
#  'mortacc',
#  'mthssincercntil',
#  'mthssincelastrecord',
#  'tothicredlim',
#  'memberid',
#  'mthssincerecentbc',
#  'numtl90gdpd24m',
#  'maxbalbc',
#  'numiltl',
#  'totalrevhilim',
#  'mthssincerecentbcdlq',
#  'ficorangelow',
#  'mthssincerecentrevoldelinq',
#  'initialliststatus',
#  'numbcsats',
#  'numsats',
#  'bcopentobuy',
#  'openil24m',
#  'applicationtype',
#  'delinqamnt',
#  'openrv24m',
#  'percentbcgt75',
#  'taxliens',
#  'installment',
#  'ficorangehigh',
#  'mosinoldilacct',
#  'subgrade',
#  'numactvrevtl',
#  'numtloppast12m',
#  'openrv12m',
#  'numactvbctl',
#  'chargeoffwithin12mths',
#  'numbctl',
#  'desc',
#  'allutil',
#  'ilutil',
#  'pubrec',
#  'bcutil',
#  'pcttlnvrdlq',
#  'totalcutl',
#  'mthssincelastmajorderog',
#  'accnowdelinq',
#  'totalbalil',
#  'totcollamt',
#  'mthssincerecentinq',
#  'mosinrcntrevtlop',
#  'openil12m',
#  'totalbclimit',
#  'dtijoint',
#  'homeownership',
#  'pubrecbankruptcies',
#  'numoprevtl',
#  'revolbal',
#  'annualinc',
#  'totalacc',
#  'mthssincelastdelinq',
#  'delinq2yrs',
#  'collections12mthsexmed',
#  'numtl30dpd',
#  'purpose',
#  'annualincjoint',
#  'mosinrcnttl',
#  'openacc6m',
#  'term',
#  'totcurbal',
#  'numrevaccts',
#  'emplength',
#  'inqlast12m',
#  'emptitle',
#  'dti',
#  'earliestcrline',
#  'intrate',
#  'addrstate',
#  'zipcode',
#  'fundedamnt',
#  'verificationstatus',
#  'verificationstatusjoint',
#  'loanamnt',
#  'numacctsever120pd',
#  'issued',
#  'loanstatus']

# %% [markdown]
# ## find common_feature existing in both current data and 2014 data

# %%
common_feature = list(set(his_feature)&(set(current_feature)))
print ("number of common features: " + str(len(common_feature)) + '\n')
print ('----------common features-----------------')
common_feature
# Out:
# number of common features: 86
#
# ----------common features-----------------
# ['homeownership',
#  'term',
#  'percentbcgt75',
#  'totalcutl',
#  'mthssincerecentbc',
#  'revolutil',
#  'numiltl',
#  'emplength',
#  'totcollamt',
#  'maxbalbc',
#  'annualinc',
#  'inqlast6mths',
#  'totalilhighcreditlimit',
#  'numtl120dpd2m',
#  'numrevtlbalgt0',
#  'pubrecbankruptcies',
#  'mthssincelastdelinq',
#  'taxliens',
#  'mosinoldrevtlop',
#  'openacc',
#  'openrv24m',
#  'totalbclimit',
#  'grade',
#  'mthssincelastmajorderog',
#  'totalacc',
#  'numbctl',
#  'delinqamnt',
#  'bcutil',
#  'numoprevtl',
#  'ficorangehigh',
#  'accopenpast24mths',
#  'mthssincerecentinq',
#  'initialliststatus',
#  'totalbalexmort',
#  'applicationtype',
#  'subgrade',
#  'mthssincelastrecord',
#  'ilutil',
#  'mthssincerecentrevoldelinq',
#  'mosinrcnttl',
#  'numbcsats',
#  'earliestcrline',
#  'desc',
#  'chargeoffwithin12mths',
#  'emptitle',
#  'tothicredlim',
#  'openrv12m',
#  'accnowdelinq',
#  'mthssincerecentbcdlq',
#  'avgcurbal',
#  'openil12m',
#  'id',
#  'delinq2yrs',
#  'intrate',
#  'mthssincercntil',
#  'numrevaccts',
#  'bcopentobuy',
#  'dti',
#  'installment',
#  'annualincjoint',
#  'dtijoint',
#  'numsats',
#  'collections12mthsexmed',
#  'addrstate',
#  'ficorangelow',
#  'inqlast12m',
#  'pubrec',
#  'mosinoldilacct',
#  'mortacc',
#  'totalrevhilim',
#  'numtloppast12m',
#  'openil24m',
#  'inqfi',
#  'memberid',
#  'allutil',
#  'totalbalil',
#  'numactvbctl',
#  'purpose',
#  'numactvrevtl',
#  'totcurbal',
#  'mosinrcntrevtlop',
#  'pcttlnvrdlq',
#  'revolbal',
#  'numtl30dpd',
#  'openacc6m',
#  'numtl90gdpd24m']

# %% [markdown]
# find historical features only existing in 2014 data  --> his_unique

# %%
his_unique= list(set(his_feature)-set(current_feature))

print ("number of features only exist in 2014 data: " + str(len(his_unique)))
print ('\n')
print ('----------2014_only features-----------------')
his_unique
# Out:
# number of features only exist in 2014 data: 8
#
#
# ----------2014_only features-----------------
# ['issued',
#  'verificationstatusjoint',
#  'verificationstatus',
#  'loanamnt',
#  'zipcode',
#  'fundedamnt',
#  'numacctsever120pd',
#  'loanstatus']

# %% [markdown]
# find current features only existing in current data --> current_unique

# %%
current_unique=list(set(current_feature)-set(his_feature))
print ("number of features only exist in current data: " + str(len(current_unique)))
print ('\n')
print ('----------current_only features-----------------')
current_unique
# Out:
# number of features only exist in current data: 33
#
#
# ----------current_only features-----------------
# ['housingpayment',
#  'acceptd',
#  'secappmortacc',
#  'numacctsever120ppd',
#  'expd',
#  'reviewstatusd',
#  'secappcollections12mthsexmed',
#  'addrzip',
#  'secappnumrevaccts',
#  'secappficorangelow',
#  'isincvjoint',
#  'secappopenactil',
#  'mtgpayment',
#  'secappinqlast6mths',
#  'secappchargeoffwithin12mths',
#  'secapprevolutil',
#  'loanamount',
#  'reviewstatus',
#  'secappficorangehigh',
#  'secappearliestcrline',
#  'disbursementmethod',
#  'isincv',
#  'secappopenacc',
#  'servicefeerate',
#  'investorcount',
#  'listd',
#  'expdefaultrate',
#  'ilsexpd',
#  'secappmthssincelastmajorderog',
#  'creditpulld',
#  'revolbaljoint',
#  'fundedamount',
#  'openactil']

# %% [markdown]
# ## save common_feature, his_unique and current feature

# %% [markdown]
# note that several features have different names in 2014 and current data, so it is necessary to manually  add them into the common feature

# %%
# mannually add several common features that are shared by current and historical data but have different names
common_feature=common_feature + ['zipcode', 
 'fundedamnt',
 'verificationstatus',
 'verificationstatusjoint',
 'loanamnt',
 'numacctsever120pd']

len(common_feature)
# Out:
# 92

# %%
# use dict feature_dic to save common_feature, his_unique feature & current_unique 
feature_dic={}
feature_dic['common_feature']=common_feature
feature_dic['his_unique']=his_unique
feature_dic['current_unique']=current_unique

# %% [markdown]
# # 4. Data Wrangling

# %%
df_2014.shape
# Out:
# (235631, 94)

# %%
df_2014.head()
# Out:
#    numtl120dpd2m  totalbalexmort  inqfi  accopenpast24mths  avgcurbal  \
# 0            0.0         15030.0    NaN                7.0     9536.0
# 1            0.0        149140.0    NaN                5.0    29828.0
# 2            0.0         38566.0    NaN                8.0     3214.0
# 3            0.0         64426.0    NaN                6.0     5857.0
# 4            0.0         18007.0    NaN                2.0    32727.0
#
#          id  mosinoldrevtlop  openacc  numrevtlbalgt0  inqlast6mths  \
# 0  36805548            290.0     17.0             9.0           2.0
# 1  38098114            244.0      6.0             4.0           0.0
# 2  37822187            265.0     12.0             7.0           0.0
# 3  37662224            148.0     11.0             4.0           1.0
# 4  37612354            170.0      8.0             5.0           0.0
#
#       ...       intrate addrstate zipcode  fundedamnt  verificationstatus  \
# 0     ...         6.99%        CA   937xx     10400.0        Not Verified
# 1     ...        12.39%        VA   235xx     15000.0     Source Verified
# 2     ...        13.66%        NJ   077xx      9600.0     Source Verified
# 3     ...        13.66%        AZ   850xx      7650.0     Source Verified
# 4     ...        17.14%        CA   953xx     12800.0            Verified
#
#    verificationstatusjoint  loanamnt  numacctsever120pd    issued   loanstatus
# 0                      NaN   10400.0                4.0  Dec-2014  Charged Off
# 1                      NaN   15000.0                0.0  Dec-2014   Fully Paid
# 2                      NaN    9600.0                0.0  Dec-2014   Fully Paid
# 3                      NaN    7650.0                0.0  Dec-2014  Charged Off
# 4                      NaN   12800.0                1.0  Dec-2014      Current
#
# [5 rows x 94 columns]

# %%
df_2014.tail()
# Out:
#         numtl120dpd2m  totalbalexmort  inqfi  accopenpast24mths  avgcurbal  \
# 235626            0.0         50896.0    NaN                7.0    28172.0
# 235627            0.0         73598.0    NaN                8.0     4089.0
# 235628            0.0         57477.0    NaN                4.0    11495.0
# 235629            NaN             NaN    NaN                NaN        NaN
# 235630            NaN             NaN    NaN                NaN        NaN
#
#                                                       id  mosinoldrevtlop  \
# 235626                                           9604874            130.0
# 235627                                           9584776             93.0
# 235628                                           9199665            166.0
# 235629  Total amount funded in policy code 1: 3503840175              NaN
# 235630   Total amount funded in policy code 2: 873652739              NaN
#
#         openacc  numrevtlbalgt0  inqlast6mths     ...      intrate addrstate  \
# 235626     21.0             3.0           1.0     ...        7.90%        CA
# 235627     18.0             2.0           2.0     ...       16.99%        OH
# 235628      6.0             2.0           0.0     ...       19.20%        CA
# 235629      NaN             NaN           NaN     ...          NaN       NaN
# 235630      NaN             NaN           NaN     ...          NaN       NaN
#
#        zipcode  fundedamnt  verificationstatus  verificationstatusjoint  \
# 235626   913xx      2000.0            Verified                      NaN
# 235627   458xx     20700.0            Verified                      NaN
# 235628   950xx     10000.0            Verified                      NaN
# 235629     NaN         NaN                 NaN                      NaN
# 235630     NaN         NaN                 NaN                      NaN
#
#         loanamnt  numacctsever120pd    issued  loanstatus
# 235626    2000.0                0.0  Jan-2014  Fully Paid
# 235627   20700.0                0.0  Jan-2014     Current
# 235628   10000.0                0.0  Jan-2014  Fully Paid
# 235629       NaN                NaN       NaN         NaN
# 235630       NaN                NaN       NaN         NaN
#
# [5 rows x 94 columns]

# %% [markdown]
# need to remove the last two rows because of invalid data

# %%
# remove last two rows
df_2014 = df_2014.iloc[:-2]
df_2014.shape
# Out:
# (235629, 94)

# %% [markdown]
# remove featues that are not existing in 2014 data
#
# Only keep common features

# %%
df_2014.term.value_counts()
# Out:
#  36 months    162570
#  60 months     73059
# Name: term, dtype: int64

# %% [markdown]
# only use term=36 months

# %%
df_2014 = df_2014.query("term ==' 36 months'")

# %%
df_2014.shape
# Out:
# (162570, 94)

# %% [markdown]
# only use loanstatus = fully paid and charged off

# %%
df_2014.loanstatus.value_counts()
# Out:
# Fully Paid            108778
# Current                31114
# Charged Off            20709
# Late (31-120 days)      1045
# In Grace Period          726
# Late (16-30 days)        194
# Default                    4
# Name: loanstatus, dtype: int64

# %%
df_2014 = df_2014.query("loanstatus == 'Fully Paid' or loanstatus == 'Charged Off' ")

# %%
df_2014.loanstatus.value_counts()
# Out:
# Fully Paid     108778
# Charged Off     20709
# Name: loanstatus, dtype: int64

# %%
df_2014.shape
# Out:
# (129487, 94)

# %% [markdown]
# removal all null featues

# %%
df_2014.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 129487 entries, 0 to 235628
# Data columns (total 94 columns):
# numtl120dpd2m                 123910 non-null float64
# totalbalexmort                129487 non-null float64
# inqfi                         0 non-null float64
# accopenpast24mths             129487 non-null float64
# avgcurbal                     129482 non-null float64
# id                            129487 non-null object
# mosinoldrevtlop               129487 non-null float64
# openacc                       129487 non-null float64
# numrevtlbalgt0                129487 non-null float64
# inqlast6mths                  129487 non-null float64
# totalilhighcreditlimit        129487 non-null float64
# revolutil                     129428 non-null object
# grade                         129487 non-null object
# mortacc                       129487 non-null float64
# mthssincercntil               0 non-null float64
# mthssincelastrecord           25307 non-null float64
# tothicredlim                  129487 non-null float64
# memberid                      0 non-null float64
# mthssincerecentbc             128251 non-null float64
# numtl90gdpd24m                129487 non-null float64
# maxbalbc                      0 non-null float64
# numiltl                       129487 non-null float64
# totalrevhilim                 129487 non-null float64
# mthssincerecentbcdlq          34690 non-null float64
# ficorangelow                  129487 non-null float64
# mthssincerecentrevoldelinq    47012 non-null float64
# initialliststatus             129487 non-null object
# numbcsats                     129487 non-null float64
# numsats                       129487 non-null float64
# bcopentobuy                   128132 non-null float64
# openil24m                     0 non-null float64
# applicationtype               129487 non-null object
# delinqamnt                    129487 non-null float64
# openrv24m                     0 non-null float64
# percentbcgt75                 128046 non-null float64
# taxliens                      129487 non-null float64
# installment                   129487 non-null float64
# ficorangehigh                 129487 non-null float64
# mosinoldilacct                125013 non-null float64
# subgrade                      129487 non-null object
# numactvrevtl                  129487 non-null float64
# numtloppast12m                129487 non-null float64
# openrv12m                     0 non-null float64
# numactvbctl                   129487 non-null float64
# chargeoffwithin12mths         129487 non-null float64
# numbctl                       129487 non-null float64
# desc                          11284 non-null object
# allutil                       0 non-null float64
# ilutil                        0 non-null float64
# pubrec                        129487 non-null float64
# bcutil                        128026 non-null float64
# pcttlnvrdlq                   129487 non-null float64
# totalcutl                     0 non-null float64
# mthssincelastmajorderog       38241 non-null float64
# accnowdelinq                  129487 non-null float64
# totalbalil                    0 non-null float64
# totcollamt                    129487 non-null float64
# mthssincerecentinq            118073 non-null float64
# mosinrcntrevtlop              129487 non-null float64
# openil12m                     0 non-null float64
# totalbclimit                  129487 non-null float64
# dtijoint                      0 non-null float64
# homeownership                 129487 non-null object
# pubrecbankruptcies            129487 non-null float64
# numoprevtl                    129487 non-null float64
# revolbal                      129487 non-null float64
# annualinc                     129487 non-null float64
# totalacc                      129487 non-null float64
# mthssincelastdelinq           65894 non-null float64
# delinq2yrs                    129487 non-null float64
# collections12mthsexmed        129487 non-null float64
# numtl30dpd                    129487 non-null float64
# purpose                       129487 non-null object
# annualincjoint                0 non-null float64
# mosinrcnttl                   129487 non-null float64
# openacc6m                     0 non-null float64
# term                          129487 non-null object
# totcurbal                     129487 non-null float64
# numrevaccts                   129487 non-null float64
# emplength                     122166 non-null object
# inqlast12m                    0 non-null float64
# emptitle                      121185 non-null object
# dti                           129487 non-null float64
# earliestcrline                129487 non-null object
# intrate                       129487 non-null object
# addrstate                     129487 non-null object
# zipcode                       129487 non-null object
# fundedamnt                    129487 non-null float64
# verificationstatus            129487 non-null object
# verificationstatusjoint       0 non-null float64
# loanamnt                      129487 non-null float64
# numacctsever120pd             129487 non-null float64
# issued                        129487 non-null object
# loanstatus                    129487 non-null object
# dtypes: float64(75), object(19)
# memory usage: 93.9+ MB

# %%
df_2014['loanstatus'].isnull().sum()
# Out:
# 0

# %%
all_null_feature = []
ob_feature = []
num_feature = []
for col in df_2014.columns.values:
    if df_2014[col].isnull().sum() == df_2014.shape[0]:
        all_null_feature.append(col)
    elif df_2014[col].dtypes == 'object':
        ob_feature.append(col)
    else:
        num_feature.append(col)

# %%
print ("all_null_feature have " + str(len(all_null_feature)) + " features")
print ("ob_feature have " + str(len(ob_feature)) + " features")
print ("num_feature have " + str(len(num_feature)) + " features")
# Out:
# all_null_feature have 17 features
# ob_feature have 19 features
# num_feature have 58 features

# %%
select_feature=ob_feature + num_feature
len(select_feature)
# Out:
# 77

# %% [markdown]
# remove low information features

# %%
#application type only has 'individual"
ob_feature.remove('applicationtype')

#no need for id, loanstatus and issued
# ob_feature.remove('id')
# ob_feature.remove('loanstatus')
# ob_feature.remove('issued')

# %% [markdown]
# remove open form feature

# %%
# remove 'desc' from ob_feature and select_feature
ob_feature.remove('desc')

# %% [markdown]
# remove redudant features

# %%
# remove fundedamnt since it always equals to 1 for issued loans and varied during different time of a current loan

num_feature.remove('fundedamnt')

# %%
select_feature=ob_feature+num_feature
len(select_feature)
# Out:
# 74

# %%
df_2014=df_2014[select_feature]

# %%
df_2014.shape
# Out:
# (129487, 74)

# %%
df_2014.verificationstatus.value_counts()
# Out:
# Not Verified       47507
# Source Verified    47370
# Verified           34610
# Name: verificationstatus, dtype: int64

# %%
df_2014.loanstatus.value_counts()
# Out:
# Fully Paid     108778
# Charged Off     20709
# Name: loanstatus, dtype: int64

# %%
df_2014['loanstatus'] = df_2014.loanstatus.map({"Charged Off": 1, "Fully Paid": 0})

# %%
df_2014.loanstatus.value_counts()
# Out:
# 0    108778
# 1     20709
# Name: loanstatus, dtype: int64

# %% [markdown]
#  ### Datetime to numeric feature

# %% [markdown]
# earliestcrline: The month the borrower's earliest reported credit line was opened

# %%
df_2014.earliestcrline.unique()[:5]
# Out:
# array(['Sep-1989', 'Nov-1992', 'Aug-2002', 'Oct-1998', 'Jan-2001'], dtype=object)

# %% [markdown]
# convert to number of months to Dec 2014

# %%
cl_month=df_2014.earliestcrline.apply(lambda x: x.split('-')[0])
cl_year=df_2014.earliestcrline.apply(lambda x: int(x.split('-')[1]))

# %%
cl_month.unique()
# Out:
# array(['Sep', 'Nov', 'Aug', 'Oct', 'Jan', 'May', 'Jul', 'Dec', 'Jun',
#        'Mar', 'Apr', 'Feb'], dtype=object)

# %%
cl_year.unique()
# Out:
# array([1989, 1992, 2002, 1998, 2001, 1999, 2009, 2003, 1993, 1995, 1996,
#        2007, 2004, 1997, 2008, 2011, 2006, 2010, 1988, 1994, 2000, 1987,
#        2005, 1986, 1973, 1982, 1991, 1984, 1976, 1974, 1981, 1990, 1978,
#        1979, 1985, 1983, 1971, 1967, 1972, 1968, 1980, 1977, 1965, 1966,
#        1975, 1969, 1963, 1970, 1964, 1958, 1962, 1959, 1955, 1960, 1961,
#        1954, 1957, 1949, 1950, 1948, 1953, 1956])

# %%
dic_month= {'Jan':11,'Feb':10,'Mar':9,'Apr':8, 'May':7, 'Jun':6, 'Jul':5, 'Aug':4, 'Sep':3, 'Oct':2, 'Nov':1, 'Dec':0}

# %%
df_2014['earliestcrline_month']=df_2014.earliestcrline.apply(lambda x: (2014-int(x.split('-')[1]))*12+dic_month[x.split('-')[0]])

# %%
df_2014.earliestcrline_month[:5]
# Out:
# 0    303
# 2    265
# 3    148
# 6    194
# 7    167
# Name: earliestcrline_month, dtype: int64

# %%
num_feature.append('earliestcrline_month')
ob_feature.remove('earliestcrline')

# %% [markdown]
# emplength

# %%
#check number of null values
print (df_2014['emplength'].isnull().sum())
df_2014['emplength'].unique()
# Out:
# 7321
# array(['8 years', '10+ years', '< 1 year', '2 years', '7 years', '9 years',
#        nan, '4 years', '3 years', '1 year', '5 years', '6 years'], dtype=object)

# %%
df_2014['emplength'].replace('n/a', np.nan, inplace=True)
df_2014['emplength'].replace('< 1 year', '0', inplace=True)
df_2014['emplength'].replace(to_replace='[^0-9]+', value='', inplace=True, regex=True)
df_2014.emplength.fillna(value=-999,inplace=True)
df_2014['emplength'] = df_2014['emplength'].astype(int)

# %%
df_2014.emplength.value_counts()
# Out:
#  10     40456
#  2      11807
#  0      10538
#  3      10523
#  1       8502
#  4       7572
#  5       7395
# -999     7321
#  7       7211
#  6       6704
#  8       6457
#  9       5001
# Name: emplength, dtype: int64

# %%
num_feature.append('emplength')
ob_feature.remove('emplength')
len(num_feature), len(ob_feature)
# Out:
# (59, 15)

# %%
## % to numeric feature: intrate, revolutil

# %%
intrate=df_2014.intrate.apply(lambda x: float(x.replace('%','')))

# %%
df_2014.intrate=intrate
df_2014.intrate[:5]
# Out:
# 0     6.99
# 2    13.66
# 3    13.66
# 6    14.31
# 7    13.66
# Name: intrate, dtype: float64

# %%
revolutil=df_2014.revolutil.apply(lambda x: str(x).replace('%','')).astype(float)

df_2014.revolutil=revolutil
df_2014.revolutil[:5]
# Out:
# 0    31.6
# 2    59.4
# 3    91.9
# 6    82.2
# 7    46.4
# Name: revolutil, dtype: float64

# %%
ob_feature.remove('intrate')
num_feature.append('intrate')
ob_feature.remove('revolutil')
num_feature.append('revolutil')

# %%
len(ob_feature), len(num_feature)
# Out:
# (13, 61)

# %% [markdown]
# Ordinal feature encoding : grade, subgrade

# %%
Dic_grade = {"A": 1, 
            "B": 2, 
            "C": 3, 
            "D": 4, 
            "E": 5,
            "F": 6, 
            "G": 7}

# %%
df_2014.grade = df_2014.grade.map(Dic_grade)

# %%
df_2014.subgrade = df_2014.subgrade.apply(lambda x: (Dic_grade[x[0]] - 1) * 5 + int(x[1]))

# %%
df_2014.subgrade.unique()
# Out:
# array([ 3, 13, 14, 10, 20,  9, 17,  8, 15, 12,  7, 11, 25, 18,  6,  5,  4,
#        16, 21,  1,  2, 22, 27, 19, 29, 23, 24, 26, 28, 31, 32, 30, 33, 34,
#        35])

# %%
ob_feature.remove('grade')
num_feature.append('grade')
ob_feature.remove('subgrade')
num_feature.append('subgrade')

# %%
len(ob_feature), len(num_feature)
# Out:
# (11, 63)

# %%
### High cardinality feature encoding

# %%
###### Zip Code - frequency encoding

# %%
df_2014.zipcode.nunique()
# Out:
# 850

# %%
df_2014.zipcode.unique()[:5]
# Out:
# array(['937xx', '077xx', '850xx', '982xx', '144xx'], dtype=object)

# %%
# convert zipcode to int
df_2014.zipcode = df_2014.zipcode.apply(lambda x: int(x[0:3]))

# %%
df_2014.zipcode[:5]
# Out:
# 0    937
# 2     77
# 3    850
# 6    982
# 7    144
# Name: zipcode, dtype: int64

# %%
zipcode_freq = df_2014.groupby("zipcode").size().reset_index()

# %%
zipcode_freq.columns = ["zipcode", "zipcode_freq"]
zipcode_freq[0:5]
# Out:
#    zipcode  zipcode_freq
# 0        8             1
# 1       10           180
# 2       11            46
# 3       12            47
# 4       13            32

# %%
df_2014 = pd.merge(df_2014, zipcode_freq, how = "left", on = "zipcode")

# %%
df_2014.zipcode_freq[:5]
# Out:
# 0    203
# 1    288
# 2    602
# 3    381
# 4    163
# Name: zipcode_freq, dtype: int64

# %%
ob_feature.remove('zipcode')
num_feature.append('zipcode')
num_feature.append('zipcode_freq')
len(ob_feature), len(num_feature)
# Out:
# (10, 65)

# %%
### emptitle-frequency encoding (can do some NLP for later stage)

# %%
emptitle_freq = df_2014.groupby("emptitle").size().reset_index()
emptitle_freq.columns = ["emptitle", "emptitle_freq"]
df_2014 = pd.merge(df_2014, emptitle_freq, how = "left", on = "emptitle")

# %%
df_2014.emptitle.head()
# Out:
# 0    Truck Driver Delivery Personel
# 1                  Admin Specialist
# 2              Technical Specialist
# 3                           Teacher
# 4                    Deputy sheriff
# Name: emptitle, dtype: object

# %%
ob_feature.remove('emptitle')
num_feature.append('emptitle_freq')
len(ob_feature), len(num_feature)
# Out:
# (9, 66)

# %%
###### Addr_state - frequency encoding

# %%
addrstate_freq = df_2014.groupby("addrstate").size().reset_index()
addrstate_freq.columns = ["addrstate", "addrstate_freq"]
df_2014 = pd.merge(df_2014, addrstate_freq, how = "left", on = "addrstate")

# %%
ob_feature.remove('addrstate')
num_feature.append('addrstate_freq')
len(ob_feature), len(num_feature)
# Out:
# (8, 67)

# %% [markdown]
# remove term as it only contains 36 month loans

# %%
ob_feature.remove('term')

# %%
len(ob_feature), len(num_feature)
# Out:
# (7, 67)

# %% [markdown]
# # 4. Save processed data in loan_2014_processed.csv

# %%
select_feature = ob_feature + num_feature

# %%
len(select_feature)
# Out:
# 74

# %%
df_2014 = df_2014[select_feature]

# %% [markdown]
# it is also necessary to convert column names in the dataframe directly

# %%
# convert column name in df_2014
for col in df_2014.columns.values:
    df_2014.rename(columns={str(col):str(col).replace('_','')}, inplace=True)

# %%
# save dataframe into loan_2014.csv
df_2014.to_csv('data/loan_2014_processed.csv',index=False)

# %%
# check saved csv file
df=pd.read_csv('data/loan_2014_processed.csv')

# %%
df.shape
# Out:
# (129487, 74)

# %%
df.columns.values
# Out:
# array(['id', 'initialliststatus', 'homeownership', 'purpose',
#        'verificationstatus', 'issued', 'loanstatus', 'numtl120dpd2m',
#        'totalbalexmort', 'accopenpast24mths', 'avgcurbal',
#        'mosinoldrevtlop', 'openacc', 'numrevtlbalgt0', 'inqlast6mths',
#        'totalilhighcreditlimit', 'mortacc', 'mthssincelastrecord',
#        'tothicredlim', 'mthssincerecentbc', 'numtl90gdpd24m', 'numiltl',
#        'totalrevhilim', 'mthssincerecentbcdlq', 'ficorangelow',
#        'mthssincerecentrevoldelinq', 'numbcsats', 'numsats', 'bcopentobuy',
#        'delinqamnt', 'percentbcgt75', 'taxliens', 'installment',
#        'ficorangehigh', 'mosinoldilacct', 'numactvrevtl', 'numtloppast12m',
#        'numactvbctl', 'chargeoffwithin12mths', 'numbctl', 'pubrec',
#        'bcutil', 'pcttlnvrdlq', 'mthssincelastmajorderog', 'accnowdelinq',
#        'totcollamt', 'mthssincerecentinq', 'mosinrcntrevtlop',
#        'totalbclimit', 'pubrecbankruptcies', 'numoprevtl', 'revolbal',
#        'annualinc', 'totalacc', 'mthssincelastdelinq', 'delinq2yrs',
#        'collections12mthsexmed', 'numtl30dpd', 'mosinrcnttl', 'totcurbal',
#        'numrevaccts', 'dti', 'loanamnt', 'numacctsever120pd',
#        'earliestcrlinemonth', 'emplength', 'intrate', 'revolutil', 'grade',
#        'subgrade', 'zipcode', 'zipcodefreq', 'emptitlefreq',
#        'addrstatefreq'], dtype=object)
